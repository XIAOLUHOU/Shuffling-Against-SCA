# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import struct
import time
from decimal import Decimal

# %% [markdown]
# # Get weight values

# %%
total_num_of_weight = 401
def get_weights_arr():
    weights_arr = []
    w_val = Decimal('-2.0')
    step = Decimal('0.01')
    for i in range (total_num_of_weight):
        weights_arr.append(float(w_val))
        w_val += step
    return weights_arr

weights_arr = get_weights_arr()
#the weight value to be recovered
true_weight = 1.43

# %% [markdown]
# # Function Definitions

# %%
def float_to_binary_str(f):
    # Pack the float into 4 bytes (32-bit) using IEEE 754 standard
    [packed] = struct.unpack('!I', struct.pack('!f', f))
    # Convert the packed number to a binary string
    return f"{packed:032b}"

# %%
def HW_float32(f):
    # Get the binary representation of the 32-bit float
    binary_str = float_to_binary_str(f)
    # Count and return the number of '1' bits
    return binary_str.count('1')

# %%
#get one part of the binary representation
def getbyte(f,byte_position):
    if byte_position == 0:#sign bit
        inbinary = float_to_binary_str(f)[0]
    elif byte_position == 4:#last 7 bits
        inbinary = float_to_binary_str(f)[25:32]
    else:
        inbinary = float_to_binary_str(f)[(byte_position-1)*8+1:byte_position*8+1]
    
    return int(inbinary,2)

# %% [markdown]
# #### The values to be recovered

# %%
#true values of different parts of the weight
true_sign_bit = getbyte(true_weight,0)
true_exponent_bits = getbyte(true_weight,1)
true_byte_two = getbyte(true_weight,2)
true_byte_three = getbyte(true_weight,3)
true_byte_four = getbyte(true_weight,4)
true_value_index = weights_arr.index(true_weight)

# %%
print("sign bit = " + str(true_sign_bit) + ", exponent = " + str(true_exponent_bits) + ", first mantissa byte = " + str(true_byte_two) + ", second mantissa byte = " + str(true_byte_three) + ", last 7 bits = " + str(true_byte_four))
# Out:
# sign bit = 0, exponent = 127, first mantissa byte = 110, second mantissa byte = 20, last 7 bits = 61

# %%
def get_hypothetical_leakages(num_of_traces, inputs_arr):
    
    # Compute all hypothetical products at once using broadcasting
    hypothetical_products = np.outer(weights_arr, inputs_arr[:num_of_traces])  # Shape: (total_num_of_weight, num_of_traces)

    # Apply the HW function element-wise using NumPy's vectorization
    hypothetical_leakages = np.vectorize(HW_float32)(hypothetical_products)  
    return np.array(hypothetical_leakages)

# %%
def recover_byte(correlation_arr, byte_position, total_time_sample):
    num_of_different_values = 256 #for byte two and three and exponent bits, we have 256 different values
    if byte_position == 0:#for sign bit, there are just 2 different values
        num_of_different_values = 2
    if byte_position == 4:#for last 7 bits, there are 2^7 different values
        num_of_different_values = 128
    correlations = [[0 for t in range(total_time_sample)] for i in range(num_of_different_values)]
    for weight_index in range(total_num_of_weight):#for each weight
        byte_value = getbyte(weights_arr[weight_index],byte_position)#for the chosen byte of this weight value
        for t in range(total_time_sample):#take the correlations for this weight value, for each time sample, update the correlations
            if correlation_arr[weight_index][t] > correlations[byte_value][t]:
                correlations[byte_value][t] = correlation_arr[weight_index][t]
        
    return correlations

# %%
#### save the plot raw data
def saveplot(foldername, filename, plot_data, arr_num_traces):                
    #save the file
    f = open(foldername + "//" + filename + ".txt", "w")    
    length = len(arr_num_traces)
    
    #first line---
    f.write("x y\n")
    #other lines
    for i in range(length):#for each line
        f.write(str(arr_num_traces[i])+" " + str(plot_data[i])+"\n")
    f.close()
    return

# %%
def find_max_and_max_true(correlation_arr, true_value_index):
    overall_max = 0
    true_max = 0
    total_plots = len(correlation_arr)
    
    for i in range(total_plots):
        if i == true_value_index:
            true_max = max(correlation_arr[i])
        else:
            w_max = max(correlation_arr[i])
            if w_max > overall_max:
                overall_max = w_max
                
    return overall_max, true_max

# %% [markdown]
# # Attack on protected traces

# %%
folder_name="protected"
num_of_traces = 50000
start = 490
end_pro = 4301
step_size = 500
total_pro = end_pro - start
print(total_pro)
# Out:
# 3811

# %%
#protected case
num_trace_arr = []
for n in range(5,95,5):
    num_trace_arr.append(n)


for n in range(100, num_of_traces, step_size):
    num_trace_arr.append(n)
num_trace_arr.append(num_of_traces)
len(num_trace_arr)
# Out:
# 119

# %%
def get_inputs(folder_name):
    with open(folder_name + '/inputs.txt') as f:
        inputs_arr = f.read().splitlines()
    f.close()
    inputs_arr = np.array(inputs_arr)
    inputs_arr = inputs_arr.astype(float)
    return inputs_arr

# %%
inputs_pro = get_inputs(folder_name)

# %%
hypothetical_leakages = get_hypothetical_leakages(num_of_traces=num_of_traces, inputs_arr=inputs_pro)

# %%
def CPA_protected(num_trace_arr, hypothetical_leakages, batch_size=10):
    total_experiment = len(num_trace_arr)
    max_traces = max(num_trace_arr)  

    r_all = np.zeros((total_experiment, total_num_of_weight, total_pro))

    print("Loading traces in batches...")

    def read_time_samples(trace_idx, start_idx, batch_size):
        with open(f"{folder_name}/trace_{trace_idx}.txt") as f:
            lines = f.readlines()[start_idx:start_idx + batch_size]
            return np.array([float(line.strip()) for line in lines])

    for batch_start in range(start, start + total_pro, batch_size):
        batch_end = min(batch_start + batch_size, start + total_pro)
        current_batch_size = batch_end - batch_start

        print(f"Processing time samples {batch_start} to {batch_end}...")
        
        start_time = time.time()

        traces = np.array([read_time_samples(i, batch_start, current_batch_size) for i in range(max_traces)])

        print("Processing trace subsets...")
        trace_subsets = np.full((total_experiment, max_traces, current_batch_size), np.nan)

        for index, trace_no in enumerate(num_trace_arr):
            trace_subsets[index, :trace_no, :current_batch_size] = traces[:trace_no, :current_batch_size].copy()

        print("Processing hypothetical leakages...")
        hypoleak_expanded = np.full((total_experiment, total_num_of_weight, max_traces), np.nan)

        for index, trace_no in enumerate(num_trace_arr):
            hypoleak_expanded[index, :, :trace_no] = hypothetical_leakages[:, :trace_no].copy()

        print("Computing correlations using np.corrcoef...")

        

        trace_slices = [trace_subsets[i, :num_trace_arr[i], :] for i in range(total_experiment)]
        hypoleak_slices = [hypoleak_expanded[i, :, :num_trace_arr[i]] for i in range(total_experiment)]

        corr_matrices = []
        for hypo, trace in zip(hypoleak_slices, trace_slices):
            combined_matrix = np.vstack([hypo, trace.T])  
            corr_matrices.append(np.corrcoef(combined_matrix))

        for i in range(total_experiment):
            corr_matrix = corr_matrices[i]

            # Extract the correct correlation values (hypothetical leakages vs. traces in the batch)
            extracted_corr = np.abs(corr_matrix[:total_num_of_weight, total_num_of_weight:total_num_of_weight + current_batch_size])
            
            # # Ensure shape consistency for the last batch
            # extracted_corr = extracted_corr[:, :current_batch_size]
            

            r_all[i, :, batch_start-start:batch_end-start] = extracted_corr  

        end_time = time.time()
        print(f"Time taken for batch {batch_start}-{batch_end}: {end_time - start_time:.2f} seconds")

    return r_all

# %%
def run_CPA_n_traces_protected(batch_size, total_ts, start_ts, save_folder, filename, arr_num_traces, hypothetical_leakages):
    # initialize np arrays for highest correlation results
    arr_max_sign_bit = np.array([])
    arr_max_true_sign_bit = np.array([])
    arr_max_exponent_bits = np.array([])
    arr_max_true_exponent_bits = np.array([])
    arr_max_byte_two = np.array([])
    arr_max_true_byte_two = np.array([])
    arr_max_byte_three = np.array([])
    arr_max_true_byte_three = np.array([])
    arr_max_byte_four = np.array([])
    arr_max_true_byte_four = np.array([])

    total_experiment = len(arr_num_traces)
    r_all = CPA_protected(num_trace_arr=arr_num_traces, hypothetical_leakages=hypothetical_leakages, batch_size=batch_size)

    for i in range(total_experiment):        
        
        if i%10 == 0:
            print("running for experiment number " + str(i))
        r = r_all[i]

        correlations_sign_bit = recover_byte(r, 0, total_ts)
        correlations_exponent_bits = recover_byte(r,1, total_ts)
        correlations_byte_two = recover_byte(r, 2, total_ts)
        correlations_byte_three = recover_byte(r, 3, total_ts)
        correlations_byte_four = recover_byte(r, 4, total_ts)

        max_sign_bit, max_true_sign_bit = find_max_and_max_true(correlations_sign_bit, true_sign_bit)
        max_exponent_bits, max_true_exponent_bits = find_max_and_max_true(correlations_exponent_bits, true_exponent_bits)
        max_byte_two, max_true_byte_two = find_max_and_max_true(correlations_byte_two, true_byte_two)
        max_byte_three, max_true_byte_three = find_max_and_max_true(correlations_byte_three, true_byte_three)
        max_byte_four, max_true_byte_four = find_max_and_max_true(correlations_byte_four, true_byte_four)

        arr_max_sign_bit = np.append(arr_max_sign_bit, max_sign_bit)
        arr_max_true_sign_bit = np.append(arr_max_true_sign_bit, max_true_sign_bit)
        arr_max_exponent_bits = np.append(arr_max_exponent_bits, max_exponent_bits)
        arr_max_true_exponent_bits = np.append(arr_max_true_exponent_bits, max_true_exponent_bits)
        arr_max_byte_two = np.append(arr_max_byte_two, max_byte_two)
        arr_max_true_byte_two = np.append(arr_max_true_byte_two, max_true_byte_two)
        arr_max_byte_three = np.append(arr_max_byte_three, max_byte_three)
        arr_max_true_byte_three = np.append(arr_max_true_byte_three, max_true_byte_three)
        arr_max_byte_four = np.append(arr_max_byte_four, max_byte_four)
        arr_max_true_byte_four = np.append(arr_max_true_byte_four, max_true_byte_four)

        if i%10 == 0:
            print("saving files")
            saveplot(save_folder, filename + "sign_bit", arr_max_sign_bit, arr_num_traces[:i])
            saveplot(save_folder, filename + "true_sign_bit", arr_max_true_sign_bit, arr_num_traces[:i])
            saveplot(save_folder, filename + "exponent_bits", arr_max_exponent_bits, arr_num_traces[:i])
            saveplot(save_folder, filename + "true_exponent_bits", arr_max_true_exponent_bits, arr_num_traces[:i])
            saveplot(save_folder, filename + "first_byte", arr_max_byte_two, arr_num_traces[:i])
            saveplot(save_folder, filename + "true_first_byte", arr_max_true_byte_two, arr_num_traces[:i])
            saveplot(save_folder, filename + "second_byte", arr_max_byte_three, arr_num_traces[:i])
            saveplot(save_folder, filename + "true_second_byte", arr_max_true_byte_three, arr_num_traces[:i])
            saveplot(save_folder, filename + "last_bits", arr_max_byte_four, arr_num_traces[:i])
            saveplot(save_folder, filename + "true_last_bits", arr_max_true_byte_four, arr_num_traces[:i])

            
    saveplot(save_folder, filename + "sign_bit", arr_max_sign_bit, arr_num_traces)
    saveplot(save_folder, filename + "true_sign_bit", arr_max_true_sign_bit, arr_num_traces)
    saveplot(save_folder, filename + "exponent_bits", arr_max_exponent_bits, arr_num_traces)
    saveplot(save_folder, filename + "true_exponent_bits", arr_max_true_exponent_bits, arr_num_traces)
    saveplot(save_folder, filename + "first_byte", arr_max_byte_two, arr_num_traces)
    saveplot(save_folder, filename + "true_first_byte", arr_max_true_byte_two, arr_num_traces)
    saveplot(save_folder, filename + "second_byte", arr_max_byte_three, arr_num_traces)
    saveplot(save_folder, filename + "true_second_byte", arr_max_true_byte_three, arr_num_traces)
    saveplot(save_folder, filename + "last_bits", arr_max_byte_four, arr_num_traces)
    saveplot(save_folder, filename + "true_last_bits", arr_max_true_byte_four, arr_num_traces)
    
    return

# %% [markdown]
# #### Results

# %%
run_CPA_n_traces_protected(batch_size = 3, total_ts=total_pro, start_ts=start, save_folder="plots_protected", filename="pro_", arr_num_traces=num_trace_arr, hypothetical_leakages=hypothetical_leakages)
# Out:
# Loading traces in batches...
# Processing time samples 490 to 493...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 490-493: 84.69 seconds
# Processing time samples 493 to 496...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 493-496: 73.51 seconds
# Processing time samples 496 to 499...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 496-499: 74.15 seconds
# Processing time samples 499 to 502...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 499-502: 74.28 seconds
# Processing time samples 502 to 505...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 502-505: 73.96 seconds
# Processing time samples 505 to 508...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 505-508: 75.62 seconds
# Processing time samples 508 to 511...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 508-511: 75.30 seconds
# Processing time samples 511 to 514...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 511-514: 75.37 seconds
# Processing time samples 514 to 517...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 514-517: 73.41 seconds
# Processing time samples 517 to 520...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 517-520: 73.94 seconds
# Processing time samples 520 to 523...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 520-523: 75.48 seconds
# Processing time samples 523 to 526...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 523-526: 74.50 seconds
# Processing time samples 526 to 529...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 526-529: 73.23 seconds
# Processing time samples 529 to 532...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 529-532: 76.04 seconds
# Processing time samples 532 to 535...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 532-535: 73.32 seconds
# Processing time samples 535 to 538...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 535-538: 73.04 seconds
# Processing time samples 538 to 541...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 538-541: 72.76 seconds
# Processing time samples 541 to 544...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 541-544: 73.57 seconds
# Processing time samples 544 to 547...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 544-547: 73.18 seconds
# Processing time samples 547 to 550...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 547-550: 72.87 seconds
# Processing time samples 550 to 553...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 550-553: 74.63 seconds
# Processing time samples 553 to 556...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 553-556: 74.32 seconds
# Processing time samples 556 to 559...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 556-559: 72.95 seconds
# Processing time samples 559 to 562...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 559-562: 73.15 seconds
# Processing time samples 562 to 565...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 562-565: 74.07 seconds
# Processing time samples 565 to 568...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 565-568: 74.05 seconds
# Processing time samples 568 to 571...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 568-571: 74.38 seconds
# Processing time samples 571 to 574...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 571-574: 74.32 seconds
# Processing time samples 574 to 577...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 574-577: 74.40 seconds
# Processing time samples 577 to 580...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 577-580: 73.84 seconds
# Processing time samples 580 to 583...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 580-583: 76.25 seconds
# Processing time samples 583 to 586...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 583-586: 74.09 seconds
# Processing time samples 586 to 589...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 586-589: 74.88 seconds
# Processing time samples 589 to 592...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 589-592: 76.38 seconds
# Processing time samples 592 to 595...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 592-595: 74.83 seconds
# Processing time samples 595 to 598...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 595-598: 74.50 seconds
# Processing time samples 598 to 601...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 598-601: 75.23 seconds
# Processing time samples 601 to 604...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 601-604: 74.64 seconds
# Processing time samples 604 to 607...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 604-607: 74.02 seconds
# Processing time samples 607 to 610...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 607-610: 74.22 seconds
# Processing time samples 610 to 613...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 610-613: 74.81 seconds
# Processing time samples 613 to 616...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 613-616: 73.98 seconds
# Processing time samples 616 to 619...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 616-619: 74.38 seconds
# Processing time samples 619 to 622...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 619-622: 73.87 seconds
# Processing time samples 622 to 625...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 622-625: 73.99 seconds
# Processing time samples 625 to 628...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 625-628: 74.38 seconds
# Processing time samples 628 to 631...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 628-631: 74.30 seconds
# Processing time samples 631 to 634...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 631-634: 74.55 seconds
# Processing time samples 634 to 637...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 634-637: 74.54 seconds
# Processing time samples 637 to 640...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 637-640: 74.31 seconds
# Processing time samples 640 to 643...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 640-643: 74.54 seconds
# Processing time samples 643 to 646...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 643-646: 75.38 seconds
# Processing time samples 646 to 649...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 646-649: 74.38 seconds
# Processing time samples 649 to 652...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 649-652: 74.80 seconds
# Processing time samples 652 to 655...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 652-655: 73.84 seconds
# Processing time samples 655 to 658...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 655-658: 73.79 seconds
# Processing time samples 658 to 661...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 658-661: 74.96 seconds
# Processing time samples 661 to 664...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 661-664: 74.52 seconds
# Processing time samples 664 to 667...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 664-667: 75.14 seconds
# Processing time samples 667 to 670...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 667-670: 74.63 seconds
# Processing time samples 670 to 673...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 670-673: 74.38 seconds
# Processing time samples 673 to 676...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 673-676: 74.61 seconds
# Processing time samples 676 to 679...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 676-679: 74.81 seconds
# Processing time samples 679 to 682...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 679-682: 74.45 seconds
# Processing time samples 682 to 685...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 682-685: 76.04 seconds
# Processing time samples 685 to 688...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 685-688: 73.66 seconds
# Processing time samples 688 to 691...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 688-691: 73.45 seconds
# Processing time samples 691 to 694...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 691-694: 73.70 seconds
# Processing time samples 694 to 697...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 694-697: 75.38 seconds
# Processing time samples 697 to 700...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 697-700: 74.64 seconds
# Processing time samples 700 to 703...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 700-703: 74.15 seconds
# Processing time samples 703 to 706...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 703-706: 74.32 seconds
# Processing time samples 706 to 709...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 706-709: 75.32 seconds
# Processing time samples 709 to 712...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 709-712: 75.38 seconds
# Processing time samples 712 to 715...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 712-715: 75.28 seconds
# Processing time samples 715 to 718...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 715-718: 75.46 seconds
# Processing time samples 718 to 721...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 718-721: 75.08 seconds
# Processing time samples 721 to 724...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 721-724: 74.98 seconds
# Processing time samples 724 to 727...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 724-727: 74.76 seconds
# Processing time samples 727 to 730...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 727-730: 75.67 seconds
# Processing time samples 730 to 733...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 730-733: 75.34 seconds
# Processing time samples 733 to 736...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 733-736: 75.07 seconds
# Processing time samples 736 to 739...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 736-739: 75.21 seconds
# Processing time samples 739 to 742...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 739-742: 75.35 seconds
# Processing time samples 742 to 745...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 742-745: 75.67 seconds
# Processing time samples 745 to 748...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 745-748: 75.63 seconds
# Processing time samples 748 to 751...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 748-751: 75.31 seconds
# Processing time samples 751 to 754...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 751-754: 75.42 seconds
# Processing time samples 754 to 757...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 754-757: 75.16 seconds
# Processing time samples 757 to 760...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 757-760: 74.70 seconds
# Processing time samples 760 to 763...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 760-763: 74.73 seconds
# Processing time samples 763 to 766...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 763-766: 75.12 seconds
# Processing time samples 766 to 769...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 766-769: 75.56 seconds
# Processing time samples 769 to 772...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 769-772: 74.98 seconds
# Processing time samples 772 to 775...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 772-775: 74.15 seconds
# Processing time samples 775 to 778...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 775-778: 73.87 seconds
# Processing time samples 778 to 781...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 778-781: 74.52 seconds
# Processing time samples 781 to 784...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 781-784: 74.83 seconds
# Processing time samples 784 to 787...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 784-787: 74.97 seconds
# Processing time samples 787 to 790...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 787-790: 77.42 seconds
# Processing time samples 790 to 793...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 790-793: 74.88 seconds
# Processing time samples 793 to 796...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 793-796: 74.24 seconds
# Processing time samples 796 to 799...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 796-799: 74.40 seconds
# Processing time samples 799 to 802...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 799-802: 74.84 seconds
# Processing time samples 802 to 805...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 802-805: 74.71 seconds
# Processing time samples 805 to 808...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 805-808: 75.19 seconds
# Processing time samples 808 to 811...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 808-811: 73.73 seconds
# Processing time samples 811 to 814...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 811-814: 74.31 seconds
# Processing time samples 814 to 817...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 814-817: 74.40 seconds
# Processing time samples 817 to 820...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 817-820: 75.57 seconds
# Processing time samples 820 to 823...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 820-823: 74.49 seconds
# Processing time samples 823 to 826...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 823-826: 74.77 seconds
# Processing time samples 826 to 829...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 826-829: 75.26 seconds
# Processing time samples 829 to 832...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 829-832: 73.96 seconds
# Processing time samples 832 to 835...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 832-835: 77.47 seconds
# Processing time samples 835 to 838...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 835-838: 78.09 seconds
# Processing time samples 838 to 841...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 838-841: 75.11 seconds
# Processing time samples 841 to 844...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 841-844: 78.23 seconds
# Processing time samples 844 to 847...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 844-847: 77.33 seconds
# Processing time samples 847 to 850...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 847-850: 74.36 seconds
# Processing time samples 850 to 853...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 850-853: 78.26 seconds
# Processing time samples 853 to 856...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 853-856: 73.14 seconds
# Processing time samples 856 to 859...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 856-859: 72.78 seconds
# Processing time samples 859 to 862...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 859-862: 73.30 seconds
# Processing time samples 862 to 865...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 862-865: 75.72 seconds
# Processing time samples 865 to 868...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 865-868: 74.88 seconds
# Processing time samples 868 to 871...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 868-871: 74.31 seconds
# Processing time samples 871 to 874...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 871-874: 74.65 seconds
# Processing time samples 874 to 877...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 874-877: 74.79 seconds
# Processing time samples 877 to 880...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 877-880: 74.77 seconds
# Processing time samples 880 to 883...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 880-883: 74.12 seconds
# Processing time samples 883 to 886...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 883-886: 74.54 seconds
# Processing time samples 886 to 889...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 886-889: 75.32 seconds
# Processing time samples 889 to 892...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 889-892: 74.91 seconds
# Processing time samples 892 to 895...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 892-895: 74.15 seconds
# Processing time samples 895 to 898...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 895-898: 74.28 seconds
# Processing time samples 898 to 901...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 898-901: 74.58 seconds
# Processing time samples 901 to 904...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 901-904: 74.66 seconds
# Processing time samples 904 to 907...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 904-907: 73.56 seconds
# Processing time samples 907 to 910...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 907-910: 74.25 seconds
# Processing time samples 910 to 913...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 910-913: 74.66 seconds
# Processing time samples 913 to 916...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 913-916: 75.30 seconds
# Processing time samples 916 to 919...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 916-919: 73.78 seconds
# Processing time samples 919 to 922...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 919-922: 74.54 seconds
# Processing time samples 922 to 925...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 922-925: 73.75 seconds
# Processing time samples 925 to 928...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 925-928: 73.37 seconds
# Processing time samples 928 to 931...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 928-931: 75.07 seconds
# Processing time samples 931 to 934...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 931-934: 75.05 seconds
# Processing time samples 934 to 937...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 934-937: 75.15 seconds
# Processing time samples 937 to 940...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 937-940: 74.48 seconds
# Processing time samples 940 to 943...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 940-943: 74.67 seconds
# Processing time samples 943 to 946...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 943-946: 73.76 seconds
# Processing time samples 946 to 949...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 946-949: 74.63 seconds
# Processing time samples 949 to 952...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 949-952: 74.46 seconds
# Processing time samples 952 to 955...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 952-955: 75.97 seconds
# Processing time samples 955 to 958...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 955-958: 74.57 seconds
# Processing time samples 958 to 961...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 958-961: 74.88 seconds
# Processing time samples 961 to 964...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 961-964: 78.14 seconds
# Processing time samples 964 to 967...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 964-967: 74.68 seconds
# Processing time samples 967 to 970...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 967-970: 74.71 seconds
# Processing time samples 970 to 973...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 970-973: 74.28 seconds
# Processing time samples 973 to 976...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 973-976: 73.75 seconds
# Processing time samples 976 to 979...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 976-979: 75.73 seconds
# Processing time samples 979 to 982...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 979-982: 75.10 seconds
# Processing time samples 982 to 985...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 982-985: 74.11 seconds
# Processing time samples 985 to 988...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 985-988: 73.26 seconds
# Processing time samples 988 to 991...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 988-991: 76.87 seconds
# Processing time samples 991 to 994...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 991-994: 76.29 seconds
# Processing time samples 994 to 997...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 994-997: 73.52 seconds
# Processing time samples 997 to 1000...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 997-1000: 74.98 seconds
# Processing time samples 1000 to 1003...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1000-1003: 74.75 seconds
# Processing time samples 1003 to 1006...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1003-1006: 75.76 seconds
# Processing time samples 1006 to 1009...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1006-1009: 75.68 seconds
# Processing time samples 1009 to 1012...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1009-1012: 75.66 seconds
# Processing time samples 1012 to 1015...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1012-1015: 73.55 seconds
# Processing time samples 1015 to 1018...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1015-1018: 76.20 seconds
# Processing time samples 1018 to 1021...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1018-1021: 74.95 seconds
# Processing time samples 1021 to 1024...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1021-1024: 77.43 seconds
# Processing time samples 1024 to 1027...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1024-1027: 77.71 seconds
# Processing time samples 1027 to 1030...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1027-1030: 78.85 seconds
# Processing time samples 1030 to 1033...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1030-1033: 76.45 seconds
# Processing time samples 1033 to 1036...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1033-1036: 75.16 seconds
# Processing time samples 1036 to 1039...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1036-1039: 74.56 seconds
# Processing time samples 1039 to 1042...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1039-1042: 75.94 seconds
# Processing time samples 1042 to 1045...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1042-1045: 77.29 seconds
# Processing time samples 1045 to 1048...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1045-1048: 76.71 seconds
# Processing time samples 1048 to 1051...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1048-1051: 74.42 seconds
# Processing time samples 1051 to 1054...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1051-1054: 75.13 seconds
# Processing time samples 1054 to 1057...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1054-1057: 74.81 seconds
# Processing time samples 1057 to 1060...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1057-1060: 74.65 seconds
# Processing time samples 1060 to 1063...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1060-1063: 76.52 seconds
# Processing time samples 1063 to 1066...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1063-1066: 74.34 seconds
# Processing time samples 1066 to 1069...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1066-1069: 74.69 seconds
# Processing time samples 1069 to 1072...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1069-1072: 75.01 seconds
# Processing time samples 1072 to 1075...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1072-1075: 73.85 seconds
# Processing time samples 1075 to 1078...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1075-1078: 73.98 seconds
# Processing time samples 1078 to 1081...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1078-1081: 74.30 seconds
# Processing time samples 1081 to 1084...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1081-1084: 73.79 seconds
# Processing time samples 1084 to 1087...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1084-1087: 74.34 seconds
# Processing time samples 1087 to 1090...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1087-1090: 74.23 seconds
# Processing time samples 1090 to 1093...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1090-1093: 74.92 seconds
# Processing time samples 1093 to 1096...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1093-1096: 73.89 seconds
# Processing time samples 1096 to 1099...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1096-1099: 74.27 seconds
# Processing time samples 1099 to 1102...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1099-1102: 73.76 seconds
# Processing time samples 1102 to 1105...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1102-1105: 74.71 seconds
# Processing time samples 1105 to 1108...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1105-1108: 75.75 seconds
# Processing time samples 1108 to 1111...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1108-1111: 74.73 seconds
# Processing time samples 1111 to 1114...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1111-1114: 74.34 seconds
# Processing time samples 1114 to 1117...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1114-1117: 73.79 seconds
# Processing time samples 1117 to 1120...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1117-1120: 74.17 seconds
# Processing time samples 1120 to 1123...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1120-1123: 74.06 seconds
# Processing time samples 1123 to 1126...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1123-1126: 74.34 seconds
# Processing time samples 1126 to 1129...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1126-1129: 74.44 seconds
# Processing time samples 1129 to 1132...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1129-1132: 74.93 seconds
# Processing time samples 1132 to 1135...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1132-1135: 73.91 seconds
# Processing time samples 1135 to 1138...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1135-1138: 73.85 seconds
# Processing time samples 1138 to 1141...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1138-1141: 77.88 seconds
# Processing time samples 1141 to 1144...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1141-1144: 74.31 seconds
# Processing time samples 1144 to 1147...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1144-1147: 73.89 seconds
# Processing time samples 1147 to 1150...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1147-1150: 75.04 seconds
# Processing time samples 1150 to 1153...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1150-1153: 74.49 seconds
# Processing time samples 1153 to 1156...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1153-1156: 73.92 seconds
# Processing time samples 1156 to 1159...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1156-1159: 73.70 seconds
# Processing time samples 1159 to 1162...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1159-1162: 73.80 seconds
# Processing time samples 1162 to 1165...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1162-1165: 73.32 seconds
# Processing time samples 1165 to 1168...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1165-1168: 73.45 seconds
# Processing time samples 1168 to 1171...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1168-1171: 77.26 seconds
# Processing time samples 1171 to 1174...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1171-1174: 73.34 seconds
# Processing time samples 1174 to 1177...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1174-1177: 74.45 seconds
# Processing time samples 1177 to 1180...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1177-1180: 73.67 seconds
# Processing time samples 1180 to 1183...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1180-1183: 73.64 seconds
# Processing time samples 1183 to 1186...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1183-1186: 74.34 seconds
# Processing time samples 1186 to 1189...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1186-1189: 75.22 seconds
# Processing time samples 1189 to 1192...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1189-1192: 75.68 seconds
# Processing time samples 1192 to 1195...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1192-1195: 77.23 seconds
# Processing time samples 1195 to 1198...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1195-1198: 75.44 seconds
# Processing time samples 1198 to 1201...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1198-1201: 74.43 seconds
# Processing time samples 1201 to 1204...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1201-1204: 74.68 seconds
# Processing time samples 1204 to 1207...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1204-1207: 74.86 seconds
# Processing time samples 1207 to 1210...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1207-1210: 74.20 seconds
# Processing time samples 1210 to 1213...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1210-1213: 74.92 seconds
# Processing time samples 1213 to 1216...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1213-1216: 76.04 seconds
# Processing time samples 1216 to 1219...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1216-1219: 76.92 seconds
# Processing time samples 1219 to 1222...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1219-1222: 75.68 seconds
# Processing time samples 1222 to 1225...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1222-1225: 75.10 seconds
# Processing time samples 1225 to 1228...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1225-1228: 75.91 seconds
# Processing time samples 1228 to 1231...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1228-1231: 75.73 seconds
# Processing time samples 1231 to 1234...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1231-1234: 76.52 seconds
# Processing time samples 1234 to 1237...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1234-1237: 76.29 seconds
# Processing time samples 1237 to 1240...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 1237-1240: 76.20 seconds
# Processing time samples 1240 to 1243...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# ...
# Computing correlations using np.corrcoef...
# Time taken for batch 4063-4066: 74.99 seconds
# Processing time samples 4066 to 4069...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4066-4069: 73.52 seconds
# Processing time samples 4069 to 4072...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4069-4072: 74.26 seconds
# Processing time samples 4072 to 4075...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4072-4075: 73.89 seconds
# Processing time samples 4075 to 4078...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4075-4078: 75.95 seconds
# Processing time samples 4078 to 4081...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4078-4081: 75.36 seconds
# Processing time samples 4081 to 4084...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4081-4084: 73.50 seconds
# Processing time samples 4084 to 4087...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4084-4087: 73.51 seconds
# Processing time samples 4087 to 4090...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4087-4090: 74.32 seconds
# Processing time samples 4090 to 4093...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4090-4093: 73.71 seconds
# Processing time samples 4093 to 4096...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4093-4096: 74.37 seconds
# Processing time samples 4096 to 4099...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4096-4099: 74.84 seconds
# Processing time samples 4099 to 4102...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4099-4102: 74.29 seconds
# Processing time samples 4102 to 4105...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4102-4105: 76.54 seconds
# Processing time samples 4105 to 4108...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4105-4108: 74.98 seconds
# Processing time samples 4108 to 4111...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4108-4111: 73.33 seconds
# Processing time samples 4111 to 4114...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4111-4114: 73.25 seconds
# Processing time samples 4114 to 4117...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4114-4117: 73.28 seconds
# Processing time samples 4117 to 4120...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4117-4120: 72.96 seconds
# Processing time samples 4120 to 4123...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4120-4123: 73.25 seconds
# Processing time samples 4123 to 4126...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4123-4126: 73.73 seconds
# Processing time samples 4126 to 4129...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4126-4129: 73.47 seconds
# Processing time samples 4129 to 4132...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4129-4132: 72.88 seconds
# Processing time samples 4132 to 4135...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4132-4135: 73.19 seconds
# Processing time samples 4135 to 4138...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4135-4138: 73.28 seconds
# Processing time samples 4138 to 4141...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4138-4141: 73.07 seconds
# Processing time samples 4141 to 4144...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4141-4144: 72.89 seconds
# Processing time samples 4144 to 4147...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4144-4147: 73.05 seconds
# Processing time samples 4147 to 4150...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4147-4150: 73.36 seconds
# Processing time samples 4150 to 4153...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4150-4153: 73.34 seconds
# Processing time samples 4153 to 4156...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4153-4156: 72.88 seconds
# Processing time samples 4156 to 4159...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4156-4159: 73.05 seconds
# Processing time samples 4159 to 4162...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4159-4162: 74.32 seconds
# Processing time samples 4162 to 4165...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4162-4165: 73.09 seconds
# Processing time samples 4165 to 4168...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4165-4168: 73.05 seconds
# Processing time samples 4168 to 4171...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4168-4171: 74.54 seconds
# Processing time samples 4171 to 4174...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4171-4174: 75.39 seconds
# Processing time samples 4174 to 4177...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4174-4177: 73.65 seconds
# Processing time samples 4177 to 4180...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4177-4180: 73.21 seconds
# Processing time samples 4180 to 4183...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4180-4183: 73.65 seconds
# Processing time samples 4183 to 4186...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4183-4186: 72.67 seconds
# Processing time samples 4186 to 4189...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4186-4189: 73.85 seconds
# Processing time samples 4189 to 4192...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4189-4192: 72.87 seconds
# Processing time samples 4192 to 4195...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4192-4195: 73.81 seconds
# Processing time samples 4195 to 4198...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4195-4198: 73.11 seconds
# Processing time samples 4198 to 4201...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4198-4201: 74.93 seconds
# Processing time samples 4201 to 4204...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4201-4204: 73.81 seconds
# Processing time samples 4204 to 4207...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4204-4207: 73.67 seconds
# Processing time samples 4207 to 4210...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4207-4210: 73.26 seconds
# Processing time samples 4210 to 4213...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4210-4213: 74.51 seconds
# Processing time samples 4213 to 4216...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4213-4216: 73.36 seconds
# Processing time samples 4216 to 4219...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4216-4219: 74.15 seconds
# Processing time samples 4219 to 4222...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4219-4222: 74.34 seconds
# Processing time samples 4222 to 4225...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4222-4225: 73.93 seconds
# Processing time samples 4225 to 4228...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4225-4228: 73.09 seconds
# Processing time samples 4228 to 4231...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4228-4231: 73.91 seconds
# Processing time samples 4231 to 4234...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4231-4234: 74.27 seconds
# Processing time samples 4234 to 4237...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4234-4237: 73.52 seconds
# Processing time samples 4237 to 4240...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4237-4240: 73.04 seconds
# Processing time samples 4240 to 4243...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4240-4243: 74.45 seconds
# Processing time samples 4243 to 4246...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4243-4246: 73.15 seconds
# Processing time samples 4246 to 4249...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4246-4249: 73.65 seconds
# Processing time samples 4249 to 4252...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4249-4252: 73.60 seconds
# Processing time samples 4252 to 4255...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4252-4255: 73.96 seconds
# Processing time samples 4255 to 4258...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4255-4258: 73.95 seconds
# Processing time samples 4258 to 4261...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4258-4261: 75.73 seconds
# Processing time samples 4261 to 4264...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4261-4264: 74.12 seconds
# Processing time samples 4264 to 4267...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4264-4267: 72.80 seconds
# Processing time samples 4267 to 4270...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4267-4270: 73.14 seconds
# Processing time samples 4270 to 4273...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4270-4273: 72.55 seconds
# Processing time samples 4273 to 4276...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4273-4276: 74.80 seconds
# Processing time samples 4276 to 4279...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4276-4279: 74.25 seconds
# Processing time samples 4279 to 4282...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4279-4282: 73.39 seconds
# Processing time samples 4282 to 4285...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4282-4285: 72.77 seconds
# Processing time samples 4285 to 4288...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4285-4288: 74.69 seconds
# Processing time samples 4288 to 4291...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4288-4291: 73.49 seconds
# Processing time samples 4291 to 4294...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4291-4294: 75.01 seconds
# Processing time samples 4294 to 4297...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4294-4297: 72.85 seconds
# Processing time samples 4297 to 4300...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4297-4300: 72.86 seconds
# Processing time samples 4300 to 4301...
# Processing trace subsets...
# Processing hypothetical leakages...
# Computing correlations using np.corrcoef...
# Time taken for batch 4300-4301: 75.21 seconds
# running for experiment number 0
# saving files
# running for experiment number 10
# saving files
# running for experiment number 20
# saving files
# running for experiment number 30
# saving files
# running for experiment number 40
# saving files
# running for experiment number 50
# saving files
# running for experiment number 60
# saving files
# running for experiment number 70
# saving files
# running for experiment number 80
# saving files
# running for experiment number 90
# saving files
# running for experiment number 100
# saving files
# running for experiment number 110
# saving files

# %% [markdown]
# ## Bound calculations

# %%
neuron_input = 7
neuron_output = 5
zalpha = 4.5
l = neuron_input*neuron_output
c = 8*zalpha*zalpha

# %% [markdown]
# $$
# \operatorname{bound} \approx\frac{110\ell^s}{\left(\ln\frac{1+\rho_1}{1-\rho_1}-\ln\frac{1+\rho_2}{1-\rho_2}\right)^2}
# $$
#
# where $\ell$ is the product of the number of input neurons and the number of output neurons of the target layer, $s=0$ for unprotected implementations and $s=2$ for the shuffling case.

# %%
def bound(shuffle, rho1, rho2):
    x = np.log((1+rho1)/(1-rho1))
    y = np.log((1+rho2)/(1-rho2))
    z = (x-y)*(x-y)
    w =(1/z)*c
    if shuffle == 1:
        w = w * l * l
    print("number of traces = " + str(w))
    #time per measurement of 450ms 
    #(including data transfer to the DUT, as well as data transfer from oscilloscope to computer and storing the data).
    t = (w*450)/(1000*60*60*24)#1ms to second, to minute, to hour, to day
    print('time = ' + str(t) + " days")
    return

# %%
def boud_DATE(shuffle, rho):
    w = 28/(rho*rho)
    if shuffle == 1:
        w = w * l * l
    print("number of traces = " + str(w) + "=" +str(w/1000000) + " million")
    #time per measurement of 450ms 
    #(including data transfer to the DUT, as well as data transfer from oscilloscope to computer and storing the data).
    t = (w*450)/(1000*60*60*24)#1ms to second, to minute, to hour, to day
    print('time = ' + str(t) + " days")
    return

# %%
def read_last_row_last_column(file_path, delimiter=None):
    """
    Reads the last row and last column from a given file.

    :param file_path: Path to the file.
    :param delimiter: Delimiter used in the file (e.g., ',' for CSV, None for whitespace).
    :return: The value in the last row and last column.
    """
    with open(file_path, 'r') as f:
        lines = f.readlines()  # Read all lines

    if not lines:
        raise ValueError("File is empty.")

    last_row = lines[-1].strip()  # Get last row, remove whitespace

    if delimiter:
        columns = last_row.split(delimiter)  # Split based on the given delimiter
    else:
        columns = last_row.split()  # Split based on whitespace

    if not columns:
        raise ValueError("Last row is empty.")

    return float(columns[-1])  # Return the last column value

# %% [markdown]
# ### Unprotected case

# %%
###exponent_bits
rho1 = read_last_row_last_column("plots_unprotected//exponent_bits.txt")
rho2 = read_last_row_last_column("plots_unprotected//true_exponent_bits.txt")
bound(0, rho1, rho2)
print("Bound from DATE")
boud_DATE(0,rho2)
# Out:
# number of traces = 59.42515104905821
# time = 0.0003095059950471782 days
# Bound from DATE
# number of traces = 31.888063070671116=3.188806307067112e-05 million
# time = 0.00016608366182641206 days

# %% [markdown]
# ### Protected case

# %%
###exponent_bits
rho1 = read_last_row_last_column("plots_protected//pro_exponent_bits.txt")
rho2 = read_last_row_last_column("plots_protected//pro_true_exponent_bits.txt")
bound(1, rho1, rho2)
print("Bound from DATE")
boud_DATE(1,rho2)
# Out:
# number of traces = 786124.6614373528
# time = 4.094399278319545 days
# Bound from DATE
# number of traces = 1318181.2901658402=1.3181812901658403 million
# time = 6.865527552947085 days

# %%
###first byte
rho1 = read_last_row_last_column("plots_protected//pro_first_byte.txt")
rho2 = read_last_row_last_column("plots_protected//pro_true_first_byte.txt")
bound(1, rho1, rho2)
print("Bound from DATE")
boud_DATE(1,rho2)
# Out:
# number of traces = 734274.1592475261
# time = 3.8243445794141984 days
# Bound from DATE
# number of traces = 1468972.772434347=1.468972772434347 million
# time = 7.650899856428891 days

# %%
###second byte
rho1 = read_last_row_last_column("plots_protected//pro_second_byte.txt")
rho2 = read_last_row_last_column("plots_protected//pro_true_second_byte.txt")
bound(1, rho1, rho2)
print("Bound from DATE")
boud_DATE(1,rho2)
# Out:
# number of traces = 734274.1592475261
# time = 3.8243445794141984 days
# Bound from DATE
# number of traces = 1468972.772434347=1.468972772434347 million
# time = 7.650899856428891 days

# %%
###last bits
rho1 = read_last_row_last_column("plots_protected//pro_last_bits.txt")
rho2 = read_last_row_last_column("plots_protected//pro_true_last_bits.txt")
bound(1, rho1, rho2)
print("Bound from DATE")
boud_DATE(1,rho2)
# Out:
# number of traces = 734274.1592475261
# time = 3.8243445794141984 days
# Bound from DATE
# number of traces = 1468972.772434347=1.468972772434347 million
# time = 7.650899856428891 days

# %% [markdown]
# ## Other codes

# %%
# import shutil
# shutil.make_archive("plots", 'zip', "plots")

# %%
##THIS ONE TRIES TO VECTORIZE EVERYTHING NO LOOPS, COMPUTING CORRELATIONS WITH PYTHON FUNCTION
#CRASHES WITH 2000 TRACES ON MAC
#def CPA_protected(num_trace_arr, hypothetical_leakages):
#     total_experiment = len(num_trace_arr)
#     max_traces = max(num_trace_arr)  # Maximum number of traces across all experiments

#     # Initialize r_all using NumPy
#     r_all = np.zeros((total_experiment, total_num_of_weight, total_pro))

#     print("Loading traces...")
#     # Efficiently read all required time samples for all traces (Shape: (max_traces, total_pro))
#     def read_time_samples(i):
#         with open(f"{folder_name}/trace_{i}.txt") as f:
#             return np.array([float(line.strip()) for line in f.readlines()[start:start + total_pro]])

#     traces = np.array([read_time_samples(i) for i in range(max_traces)])  # Shape: (max_traces, total_pro)

#     print("Real leakages computations...")
#     # **Preallocate expanded trace subsets array**
#     trace_subsets = np.full((total_experiment, max_traces, total_pro), np.nan)  # Fill with NaNs

#     # Fill trace subsets dynamically
#     for index, trace_no in enumerate(num_trace_arr):
#         trace_subsets[index, :trace_no, :] = traces[:trace_no, :]

#     print("Hypothetical leakages computations...")
#     # **Preallocate and fill hypothetical leakages**
#     hypoleak_expanded = np.full((total_experiment, total_num_of_weight, max_traces), np.nan)  # Fill with NaNs
#     for index, trace_no in enumerate(num_trace_arr):
#         hypoleak_expanded[index, :, :trace_no] = hypothetical_leakages[:, :trace_no]

#     print("Preparing for correlation computations...")
#     # Expand hypoleak_expanded along last axis to match trace_subsets (total_pro)
#     hypoleak_expanded = np.repeat(hypoleak_expanded[:, :, :, None], total_pro, axis=-1)  # Shape: (total_experiment, total_num_of_weight, max_traces, total_pro)

#     # Ensure trace_subsets is correctly shaped for concatenation
#     trace_subsets = trace_subsets[:, None, :, :]  # Shape: (total_experiment, 1, max_traces, total_pro)

#     # Concatenate hypothetical leakages and traces along axis=1
#     combined_matrix = np.concatenate([hypoleak_expanded, trace_subsets], axis=1)  # Shape: (total_experiment, total_num_of_weight+1, max_traces, total_pro)

#     print("Computing correlations in parallel...")
#     # Compute correlation matrix for all time samples at once (fully vectorized)
#     corr_matrix = np.array([[np.corrcoef(combined_matrix[exp, :, :, t])[0:-1, -1] for t in range(total_pro)] for exp in range(total_experiment)])

#     # Store absolute correlation values
#     r_all = np.abs(corr_matrix).transpose(0, 2, 1)  # Shape: (total_experiment, total_num_of_weight, total_pro)

#     return r_all

# %%
#THIS FUNCTION LOADS ALL TRACE DATA, BUT CRASHES ON BOTH COMPUTERS
# def CPA_protected(num_trace_arr, hypothetical_leakages):
#     total_experiment = len(num_trace_arr)
#     max_traces = max(num_trace_arr)  # Maximum number of traces across all experiments

#     # Initialize r_all using NumPy
#     r_all = np.zeros((total_experiment, total_num_of_weight, total_pro))

#     print("Loading traces...")
#     # Efficiently read all required time samples for all traces (Shape: (max_traces, total_pro))
#     def read_time_samples(i):
#         with open(f"{folder_name}/trace_{i}.txt") as f:
#             return np.array([float(line.strip()) for line in f.readlines()[start:start + total_pro]])

#     traces = np.array([read_time_samples(i) for i in range(max_traces)])  # Shape: (max_traces, total_pro)

#     print("Real leakages computations...")
#     trace_subsets = np.full((total_experiment, max_traces, total_pro), np.nan)  # Fill with NaNs

#     # Fill trace subsets dynamically
#     for index, trace_no in enumerate(num_trace_arr):
#         trace_subsets[index, :trace_no, :] = traces[:trace_no, :]

#     print("Hypothetical leakages computations...")
#     hypoleak_expanded = np.full((total_experiment, total_num_of_weight, max_traces), np.nan)

#     for index, trace_no in enumerate(num_trace_arr):
#         hypoleak_expanded[index, :, :trace_no] = hypothetical_leakages[:, :trace_no]

#     print("Computing correlations using np.corrcoef...")

#     start_time = time.time()  # Start timing

#     for i in range(total_pro):
#         if i % 100 == 0 and i > 0:  # Log the time taken every 10 time samples
#             elapsed_time = time.time() - start_time
#             print(f"Time taken for {i} time samples: {elapsed_time:.2f} seconds")
#             start_time = time.time()  # Reset the timer for the next batch

#         # Extract traces at current time sample
#         traces_at_time_sample = trace_subsets[:, :, i]  # Shape: (total_experiment, max_traces)

#         # Compute correlation for all experiments in parallel
#         for index in range(total_experiment):
#             trace_no = num_trace_arr[index]
#             trace_slice = traces_at_time_sample[index, :trace_no]  # Shape: (trace_no,)
#             hypoleak_slice = hypoleak_expanded[index, :, :trace_no]  # Shape: (total_num_of_weight, trace_no)

#             # Stack traces and hypothetical leakages together for correlation computation
#             combined_matrix = np.vstack([hypoleak_slice, trace_slice])  # Shape: (total_num_of_weight+1, trace_no)

#             # Compute correlation matrix
#             corr_matrix = np.corrcoef(combined_matrix)  # Shape: (total_num_of_weight+1, total_num_of_weight+1)

#             # Extract correlation values (last row, except last element)
#             r_all[index, :, i] = np.abs(corr_matrix[:-1, -1])  # Extract absolute correlation

#     return r_all

# %%
#THIS ONE TRIES TO VECTORIZE EVERYTHING NO LOOPS, COMPUTING CORRELATIONS FROM SCRATCH
#CRASHES WITH 2000 TRACES ON MAC
#def CPA_protected(num_trace_arr, hypothetical_leakages):
#     total_experiment = len(num_trace_arr)
#     max_traces = max(num_trace_arr)  # Maximum number of traces across all experiments

#     # Initialize r_all using NumPy
#     r_all = np.zeros((total_experiment, total_num_of_weight, total_pro))
    
#     print("Loading traces...")
#     # Efficiently read all required time samples for all traces (Shape: (max_traces, total_pro))
#     def read_time_samples(i):
#         with open(f"{folder_name}/trace_{i}.txt") as f:
#             return np.array([float(line.strip()) for line in f.readlines()[start:start + total_pro]])

#     traces = np.array([read_time_samples(i) for i in range(max_traces)])  # Shape: (max_traces, total_pro)

#     print("Real leakages computations...")
#     # **Fix: Preallocate the expanded trace subsets array**
#     trace_subsets = np.full((total_experiment, max_traces, total_pro), np.nan)  # Fill with NaNs

#     # Fill trace subsets dynamically
#     for index, trace_no in enumerate(num_trace_arr):
#         trace_subsets[index, :trace_no, :] = traces[:trace_no, :]

#     # Compute mean and variance for traces (Shape: (total_experiment, 1, total_pro))
#     mean_traces = np.nanmean(trace_subsets, axis=1, keepdims=True)  # Ignore NaNs
#     trace_dev = trace_subsets - mean_traces  # Shape: (total_experiment, max_traces, total_pro)
#     var_traces = np.nansum(trace_dev**2, axis=1, keepdims=True)  # Shape: (total_experiment, 1, total_pro)
    
#     print("Hypothetical leakages computations...")
#     # **Fix: Preallocate and fill hypothetical leakages**
#     hypoleak_expanded = np.full((total_experiment, total_num_of_weight, max_traces), np.nan)  # Fill with NaNs
#     for index, trace_no in enumerate(num_trace_arr):
#         hypoleak_expanded[index, :, :trace_no] = hypothetical_leakages[:, :trace_no]

#     # Precompute means and variances for hypothetical leakages (Shape: (total_experiment, total_num_of_weight, 1))
#     precomputed_means = np.nanmean(hypoleak_expanded, axis=2, keepdims=True)  # Ignore NaNs
#     precomputed_variances = np.nansum((hypoleak_expanded - precomputed_means) ** 2, axis=2, keepdims=True)

#     print("Correlations computations...")
#     # Compute correlation for all time samples at once (fully vectorized)
#     # **Fix: Reshape trace_dev to match the expected broadcasting dimensions**
#     trace_dev = trace_dev[:, None, :, :]  # Shape: (experiments, 1, traces, time samples)

#     num_samples = np.expand_dims(num_trace_arr, axis=(1,2))  # Shape: (total_experiment, 1, 1)

#     # Compute correlation properly (divide by N)
#     num = np.nansum((hypoleak_expanded - precomputed_means)[:, :, :, None] * trace_dev, axis=2) / num_samples
#     den = np.sqrt(precomputed_variances * var_traces) / num_samples

#     r_all = np.abs(num / den)  # Store absolute correlation


#     return r_all
