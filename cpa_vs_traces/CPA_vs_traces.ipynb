# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import struct
import time
from decimal import Decimal

# %% [markdown]
# # Get weight values

# %%
total_num_of_weight = 401
def get_weights_arr():
    weights_arr = []
    w_val = Decimal('-2.0')
    step = Decimal('0.01')
    for i in range (total_num_of_weight):
        weights_arr.append(float(w_val))
        w_val += step
    return weights_arr

weights_arr = get_weights_arr()
#the weight value to be recovered
true_weight = 1.43

# %% [markdown]
# # Function Definitions

# %%
def float_to_binary_str(f):
    # Pack the float into 4 bytes (32-bit) using IEEE 754 standard
    [packed] = struct.unpack('!I', struct.pack('!f', f))
    # Convert the packed number to a binary string
    return f"{packed:032b}"

# %%
def HW_float32(f):
    # Get the binary representation of the 32-bit float
    binary_str = float_to_binary_str(f)
    # Count and return the number of '1' bits
    return binary_str.count('1')

# %%
#get one part of the binary representation
def getbyte(f,byte_position):
    if byte_position == 0:#sign bit
        inbinary = float_to_binary_str(f)[0]
    elif byte_position == 4:#last 7 bits
        inbinary = float_to_binary_str(f)[25:32]
    else:
        inbinary = float_to_binary_str(f)[(byte_position-1)*8+1:byte_position*8+1]
    
    return int(inbinary,2)

# %% [markdown]
# #### The values to be recovered

# %%
#true values of different parts of the weight
true_sign_bit = getbyte(true_weight,0)
true_exponent_bits = getbyte(true_weight,1)
true_byte_two = getbyte(true_weight,2)
true_byte_three = getbyte(true_weight,3)
true_byte_four = getbyte(true_weight,4)
true_value_index = weights_arr.index(true_weight)

# %%
print("sign bit = " + str(true_sign_bit) + ", exponent = " + str(true_exponent_bits) + ", first mantissa byte = " + str(true_byte_two) + ", second mantissa byte = " + str(true_byte_three) + ", last 7 bits = " + str(true_byte_four))
# Out:
# sign bit = 0, exponent = 127, first mantissa byte = 110, second mantissa byte = 20, last 7 bits = 61

# %%
def get_hypothetical_leakages(num_of_traces, inputs_arr):
    hypothetical_leakages = [[] for i in range(total_num_of_weight)]
    for weight_index in range(total_num_of_weight):
        for j in range(num_of_traces):
            #compute the hypothetical product values for each hypothetical value of weight and each random input
            hypothetical_product = weights_arr[weight_index] * inputs_arr[j]
            #compute hypothetical leakages
            hypothetical_leakages[weight_index].append(HW_float32(hypothetical_product))
    return np.array(hypothetical_leakages)

# %%
def CPA_attack(num_of_traces, total_time_sample, start_time_sample, trace_arr, hypothetical_leakages):
    r_abs = [[] for i in range(total_num_of_weight)]
    for t in range(total_time_sample):
        time_sample_index = t + start_time_sample
        for weight_index in range(total_num_of_weight):
            corr_coef = np.corrcoef(hypothetical_leakages[weight_index],trace_arr[:,time_sample_index])[0][1]
            r_abs[weight_index].append(abs(corr_coef))
    return r_abs

# %%
def recover_byte(correlation_arr, byte_position, total_time_sample):
    num_of_different_values = 256 #for byte two and three and exponent bits, we have 256 different values
    if byte_position == 0:#for sign bit, there are just 2 different values
        num_of_different_values = 2
    if byte_position == 4:#for last 7 bits, there are 2^7 different values
        num_of_different_values = 128
    correlations = [[0 for t in range(total_time_sample)] for i in range(num_of_different_values)]
    for weight_index in range(total_num_of_weight):#for each weight
        byte_value = getbyte(weights_arr[weight_index],byte_position)#for the chosen byte of this weight value
        for t in range(total_time_sample):#take the correlations for this weight value, for each time sample, update the correlations
            if correlation_arr[weight_index][t] > correlations[byte_value][t]:
                correlations[byte_value][t] = correlation_arr[weight_index][t]
        
    return correlations

# %%
def plot_correlations(correlation, value_index, total_time_sample, start_time_sample):
    x = []
    total_plots = len(correlation)
    
    for t in range(total_time_sample):
        x.append(t+start_time_sample)
    
    plt.plot(x,correlation[value_index], color="r")
    
    for i in range(total_plots):
        if i == value_index:
            continue
        else: 
            plt.plot(x,correlation[i], color="#808080")
    return

# %%
def savefile(foldername, filename, arr, total_time_sample, start_time_sample):
    f = open(foldername + "//" + filename + ".txt", "w")
    length = len(arr)#number of columns
    
    
    #first line
    f.write("x ")
    for i in range(length):
        f.write("y"+str(i)+" ")
    f.write("\n")
    
    for t in range(total_time_sample):#for each line
        f.write(str(t+start_time_sample)+" ")#first write down the time sample
        for j in range(length):
            f.write(str(arr[j][t])+" ")
        f.write("\n")
    f.close()
    return

# %%
def load_traces(num_of_traces, folder_name):
    trace_waves_arr = []
    inputs_arr = []

    for i in range(num_of_traces):
        with open(folder_name + '/trace_'+str(i)+'.txt') as f:
            lines = f.read().splitlines()
            trace_waves_arr.append(lines)

    with open(folder_name + '/inputs.txt') as f:
        inputs_arr = f.read().splitlines()
    trace_waves_arr = np.array(trace_waves_arr)
    trace_waves_arr = trace_waves_arr.astype(float)

    inputs_arr = np.array(inputs_arr)
    inputs_arr = inputs_arr.astype(float)
    return trace_waves_arr, inputs_arr

# %%
#### save the plot raw data
def saveplot(foldername, filename, plot_data, arr_num_traces):                
    #save the file
    f = open(foldername + "//" + filename + ".txt", "w")    
    length = len(arr_num_traces)
    
    #first line---
    f.write("x y\n")
    #other lines
    for i in range(length):#for each line
        f.write(str(arr_num_traces[i])+" " + str(plot_data[i])+"\n")
    f.close()
    return

# %%
def find_max_and_max_true(correlation_arr, true_value_index):
    overall_max = 0
    true_max = 0
    total_plots = len(correlation_arr)
    
    for i in range(total_plots):
        if i == true_value_index:
            true_max = max(correlation_arr[i])
        else:
            w_max = max(correlation_arr[i])
            if w_max > overall_max:
                overall_max = w_max
                
    return overall_max, true_max

# %%
def run_CPA_n_traces(total_ts, start_ts, trace_arr, save_folder, filename, arr_num_traces, hypothetical_leakages):
    # initialize np arrays for highest correlation results
    arr_max_sign_bit = np.array([])
    arr_max_true_sign_bit = np.array([])
    arr_max_exponent_bits = np.array([])
    arr_max_true_exponent_bits = np.array([])
    arr_max_byte_two = np.array([])
    arr_max_true_byte_two = np.array([])
    arr_max_byte_three = np.array([])
    arr_max_true_byte_three = np.array([])
    arr_max_byte_four = np.array([])
    arr_max_true_byte_four = np.array([])

    total_experiment = len(arr_num_traces)

    start_time = time.time()
    for i in range(total_experiment):
        trace_no = arr_num_traces[i]
        print(f'Running CPA for num_of_traces = {trace_no}')
        
        ind = [j for j in range(trace_no)]
        
        traces = trace_arr[ind]
        hypoleak = hypothetical_leakages[:,ind]#extract the corresponding hypothetical leakages
        r = CPA_attack(num_of_traces=trace_no, total_time_sample=total_ts, start_time_sample=start_ts, trace_arr=traces, hypothetical_leakages=hypoleak)

        print(f'CPA attack for num_of_traces = {trace_no} and ({start}-{start + total_ts}) time samples complete in {time.time() - start_time}!')
        correlations_sign_bit = recover_byte(r, 0, total_ts)
        correlations_exponent_bits = recover_byte(r,1, total_ts)
        correlations_byte_two = recover_byte(r, 2, total_ts)
        correlations_byte_three = recover_byte(r, 3, total_ts)
        correlations_byte_four = recover_byte(r, 4, total_ts)

        max_sign_bit, max_true_sign_bit = find_max_and_max_true(correlations_sign_bit, true_sign_bit)
        max_exponent_bits, max_true_exponent_bits = find_max_and_max_true(correlations_exponent_bits, true_exponent_bits)
        max_byte_two, max_true_byte_two = find_max_and_max_true(correlations_byte_two, true_byte_two)
        max_byte_three, max_true_byte_three = find_max_and_max_true(correlations_byte_three, true_byte_three)
        max_byte_four, max_true_byte_four = find_max_and_max_true(correlations_byte_four, true_byte_four)

        arr_max_sign_bit = np.append(arr_max_sign_bit, max_sign_bit)
        arr_max_true_sign_bit = np.append(arr_max_true_sign_bit, max_true_sign_bit)
        arr_max_exponent_bits = np.append(arr_max_exponent_bits, max_exponent_bits)
        arr_max_true_exponent_bits = np.append(arr_max_true_exponent_bits, max_true_exponent_bits)
        arr_max_byte_two = np.append(arr_max_byte_two, max_byte_two)
        arr_max_true_byte_two = np.append(arr_max_true_byte_two, max_true_byte_two)
        arr_max_byte_three = np.append(arr_max_byte_three, max_byte_three)
        arr_max_true_byte_three = np.append(arr_max_true_byte_three, max_true_byte_three)
        arr_max_byte_four = np.append(arr_max_byte_four, max_byte_four)
        arr_max_true_byte_four = np.append(arr_max_true_byte_four, max_true_byte_four)

        if i%100000 == 0:
            saveplot(save_folder, filename + "sign_bit", arr_max_sign_bit, arr_num_traces)
            saveplot(save_folder, filename + "true_sign_bit", arr_max_true_sign_bit, arr_num_traces)
            saveplot(save_folder, filename + "exponent_bits", arr_max_exponent_bits, arr_num_traces)
            saveplot(save_folder, filename + "true_exponent_bits", arr_max_true_exponent_bits, arr_num_traces)
            saveplot(save_folder, filename + "first_byte", arr_max_byte_two, arr_num_traces)
            saveplot(save_folder, filename + "true_first_byte", arr_max_true_byte_two, arr_num_traces)
            saveplot(save_folder, filename + "second_byte", arr_max_byte_three, arr_num_traces)
            saveplot(save_folder, filename + "true_second_byte", arr_max_true_byte_three, arr_num_traces)
            saveplot(save_folder, filename + "last_bits", arr_max_byte_four, arr_num_traces)
            saveplot(save_folder, filename + "true_last_bits", arr_max_true_byte_four, arr_num_traces)
            
    saveplot(save_folder, filename + "sign_bit", arr_max_sign_bit, arr_num_traces)
    saveplot(save_folder, filename + "true_sign_bit", arr_max_true_sign_bit, arr_num_traces)
    saveplot(save_folder, filename + "exponent_bits", arr_max_exponent_bits, arr_num_traces)
    saveplot(save_folder, filename + "true_exponent_bits", arr_max_true_exponent_bits, arr_num_traces)
    saveplot(save_folder, filename + "first_byte", arr_max_byte_two, arr_num_traces)
    saveplot(save_folder, filename + "true_first_byte", arr_max_true_byte_two, arr_num_traces)
    saveplot(save_folder, filename + "second_byte", arr_max_byte_three, arr_num_traces)
    saveplot(save_folder, filename + "true_second_byte", arr_max_true_byte_three, arr_num_traces)
    saveplot(save_folder, filename + "last_bits", arr_max_byte_four, arr_num_traces)
    saveplot(save_folder, filename + "true_last_bits", arr_max_true_byte_four, arr_num_traces)
    
    return

# %% [markdown]
# # Attack on unprotected traces

# %%
traces, inputs = load_traces(num_of_traces=5000, folder_name="unprotected")
hypothetical_leakages = get_hypothetical_leakages(num_of_traces=5000, inputs_arr=inputs)

# %%
start = 490
end = 1011
total = end - start

# %%
#unprotected case
num_trace = []
for n in range(3,21):
    num_trace.append(n)
for n in range(40,5020,20):
    num_trace.append(n)

# %%
run_CPA_n_traces(total_ts=total, start_ts=start, trace_arr=traces, save_folder="plots_unprotected", filename="", arr_num_traces=num_trace, hypothetical_leakages=hypothetical_leakages)
# Out:
# Running CPA for num_of_traces = 3
# CPA attack for num_of_traces = 3 and (490-1011) time samples complete in 8.785578966140747!
# Running CPA for num_of_traces = 4
# CPA attack for num_of_traces = 4 and (490-1011) time samples complete in 17.639158010482788!
# Running CPA for num_of_traces = 5
# CPA attack for num_of_traces = 5 and (490-1011) time samples complete in 26.514605045318604!
# Running CPA for num_of_traces = 6
# CPA attack for num_of_traces = 6 and (490-1011) time samples complete in 35.40126299858093!
# Running CPA for num_of_traces = 7
# CPA attack for num_of_traces = 7 and (490-1011) time samples complete in 44.26145887374878!
# Running CPA for num_of_traces = 8
# CPA attack for num_of_traces = 8 and (490-1011) time samples complete in 53.101141929626465!
# Running CPA for num_of_traces = 9
# CPA attack for num_of_traces = 9 and (490-1011) time samples complete in 62.1882438659668!
# Running CPA for num_of_traces = 10
# CPA attack for num_of_traces = 10 and (490-1011) time samples complete in 71.94774103164673!
# Running CPA for num_of_traces = 11
# CPA attack for num_of_traces = 11 and (490-1011) time samples complete in 81.54536390304565!
# Running CPA for num_of_traces = 12
# CPA attack for num_of_traces = 12 and (490-1011) time samples complete in 90.45659017562866!
# Running CPA for num_of_traces = 13
# CPA attack for num_of_traces = 13 and (490-1011) time samples complete in 99.7333550453186!
# Running CPA for num_of_traces = 14
# CPA attack for num_of_traces = 14 and (490-1011) time samples complete in 108.74920606613159!
# Running CPA for num_of_traces = 15
# CPA attack for num_of_traces = 15 and (490-1011) time samples complete in 117.544105052948!
# Running CPA for num_of_traces = 16
# CPA attack for num_of_traces = 16 and (490-1011) time samples complete in 126.30252599716187!
# Running CPA for num_of_traces = 17
# CPA attack for num_of_traces = 17 and (490-1011) time samples complete in 135.1236391067505!
# Running CPA for num_of_traces = 18
# CPA attack for num_of_traces = 18 and (490-1011) time samples complete in 143.92155694961548!
# Running CPA for num_of_traces = 19
# CPA attack for num_of_traces = 19 and (490-1011) time samples complete in 152.70559000968933!
# Running CPA for num_of_traces = 20
# CPA attack for num_of_traces = 20 and (490-1011) time samples complete in 161.51159286499023!
# Running CPA for num_of_traces = 40
# CPA attack for num_of_traces = 40 and (490-1011) time samples complete in 170.52181100845337!
# Running CPA for num_of_traces = 60
# CPA attack for num_of_traces = 60 and (490-1011) time samples complete in 179.5452721118927!
# Running CPA for num_of_traces = 80
# CPA attack for num_of_traces = 80 and (490-1011) time samples complete in 188.6467800140381!
# Running CPA for num_of_traces = 100
# CPA attack for num_of_traces = 100 and (490-1011) time samples complete in 197.7566740512848!
# Running CPA for num_of_traces = 120
# CPA attack for num_of_traces = 120 and (490-1011) time samples complete in 206.89988923072815!
# Running CPA for num_of_traces = 140
# CPA attack for num_of_traces = 140 and (490-1011) time samples complete in 216.26656413078308!
# Running CPA for num_of_traces = 160
# CPA attack for num_of_traces = 160 and (490-1011) time samples complete in 225.63065600395203!
# Running CPA for num_of_traces = 180
# CPA attack for num_of_traces = 180 and (490-1011) time samples complete in 235.31950116157532!
# Running CPA for num_of_traces = 200
# CPA attack for num_of_traces = 200 and (490-1011) time samples complete in 244.90567183494568!
# Running CPA for num_of_traces = 220
# CPA attack for num_of_traces = 220 and (490-1011) time samples complete in 254.64893412590027!
# Running CPA for num_of_traces = 240
# CPA attack for num_of_traces = 240 and (490-1011) time samples complete in 264.13116908073425!
# Running CPA for num_of_traces = 260
# CPA attack for num_of_traces = 260 and (490-1011) time samples complete in 273.95592498779297!
# Running CPA for num_of_traces = 280
# CPA attack for num_of_traces = 280 and (490-1011) time samples complete in 283.74094319343567!
# Running CPA for num_of_traces = 300
# CPA attack for num_of_traces = 300 and (490-1011) time samples complete in 294.0016040802002!
# Running CPA for num_of_traces = 320
# CPA attack for num_of_traces = 320 and (490-1011) time samples complete in 303.8966770172119!
# Running CPA for num_of_traces = 340
# CPA attack for num_of_traces = 340 and (490-1011) time samples complete in 313.6468391418457!
# Running CPA for num_of_traces = 360
# CPA attack for num_of_traces = 360 and (490-1011) time samples complete in 323.6702079772949!
# Running CPA for num_of_traces = 380
# CPA attack for num_of_traces = 380 and (490-1011) time samples complete in 333.50718903541565!
# Running CPA for num_of_traces = 400
# CPA attack for num_of_traces = 400 and (490-1011) time samples complete in 343.38410997390747!
# Running CPA for num_of_traces = 420
# CPA attack for num_of_traces = 420 and (490-1011) time samples complete in 353.5848729610443!
# Running CPA for num_of_traces = 440
# CPA attack for num_of_traces = 440 and (490-1011) time samples complete in 363.5984330177307!
# Running CPA for num_of_traces = 460
# CPA attack for num_of_traces = 460 and (490-1011) time samples complete in 373.5642991065979!
# Running CPA for num_of_traces = 480
# CPA attack for num_of_traces = 480 and (490-1011) time samples complete in 383.7222681045532!
# Running CPA for num_of_traces = 500
# CPA attack for num_of_traces = 500 and (490-1011) time samples complete in 393.7164180278778!
# Running CPA for num_of_traces = 520
# CPA attack for num_of_traces = 520 and (490-1011) time samples complete in 404.2064230442047!
# Running CPA for num_of_traces = 540
# CPA attack for num_of_traces = 540 and (490-1011) time samples complete in 414.46700501441956!
# Running CPA for num_of_traces = 560
# CPA attack for num_of_traces = 560 and (490-1011) time samples complete in 424.6976492404938!
# Running CPA for num_of_traces = 580
# CPA attack for num_of_traces = 580 and (490-1011) time samples complete in 435.2154459953308!
# Running CPA for num_of_traces = 600
# CPA attack for num_of_traces = 600 and (490-1011) time samples complete in 445.58003997802734!
# Running CPA for num_of_traces = 620
# CPA attack for num_of_traces = 620 and (490-1011) time samples complete in 456.2702362537384!
# Running CPA for num_of_traces = 640
# CPA attack for num_of_traces = 640 and (490-1011) time samples complete in 466.7471270561218!
# Running CPA for num_of_traces = 660
# CPA attack for num_of_traces = 660 and (490-1011) time samples complete in 477.20503401756287!
# Running CPA for num_of_traces = 680
# CPA attack for num_of_traces = 680 and (490-1011) time samples complete in 487.98513412475586!
# Running CPA for num_of_traces = 700
# CPA attack for num_of_traces = 700 and (490-1011) time samples complete in 498.370628118515!
# Running CPA for num_of_traces = 720
# CPA attack for num_of_traces = 720 and (490-1011) time samples complete in 509.02200508117676!
# Running CPA for num_of_traces = 740
# CPA attack for num_of_traces = 740 and (490-1011) time samples complete in 519.4984400272369!
# Running CPA for num_of_traces = 760
# CPA attack for num_of_traces = 760 and (490-1011) time samples complete in 530.0277240276337!
# Running CPA for num_of_traces = 780
# CPA attack for num_of_traces = 780 and (490-1011) time samples complete in 540.678365945816!
# Running CPA for num_of_traces = 800
# CPA attack for num_of_traces = 800 and (490-1011) time samples complete in 551.2106909751892!
# Running CPA for num_of_traces = 820
# CPA attack for num_of_traces = 820 and (490-1011) time samples complete in 562.178628206253!
# Running CPA for num_of_traces = 840
# CPA attack for num_of_traces = 840 and (490-1011) time samples complete in 572.7983181476593!
# Running CPA for num_of_traces = 860
# CPA attack for num_of_traces = 860 and (490-1011) time samples complete in 583.5208702087402!
# Running CPA for num_of_traces = 880
# CPA attack for num_of_traces = 880 and (490-1011) time samples complete in 594.4336869716644!
# Running CPA for num_of_traces = 900
# CPA attack for num_of_traces = 900 and (490-1011) time samples complete in 605.190327167511!
# Running CPA for num_of_traces = 920
# CPA attack for num_of_traces = 920 and (490-1011) time samples complete in 616.295440196991!
# Running CPA for num_of_traces = 940
# CPA attack for num_of_traces = 940 and (490-1011) time samples complete in 627.0656440258026!
# Running CPA for num_of_traces = 960
# CPA attack for num_of_traces = 960 and (490-1011) time samples complete in 638.155601978302!
# Running CPA for num_of_traces = 980
# CPA attack for num_of_traces = 980 and (490-1011) time samples complete in 649.3028211593628!
# Running CPA for num_of_traces = 1000
# CPA attack for num_of_traces = 1000 and (490-1011) time samples complete in 660.2497050762177!
# Running CPA for num_of_traces = 1020
# CPA attack for num_of_traces = 1020 and (490-1011) time samples complete in 671.6263558864594!
# Running CPA for num_of_traces = 1040
# CPA attack for num_of_traces = 1040 and (490-1011) time samples complete in 682.8323440551758!
# Running CPA for num_of_traces = 1060
# CPA attack for num_of_traces = 1060 and (490-1011) time samples complete in 694.1602940559387!
# Running CPA for num_of_traces = 1080
# CPA attack for num_of_traces = 1080 and (490-1011) time samples complete in 705.5804059505463!
# Running CPA for num_of_traces = 1100
# CPA attack for num_of_traces = 1100 and (490-1011) time samples complete in 716.8671360015869!
# Running CPA for num_of_traces = 1120
# CPA attack for num_of_traces = 1120 and (490-1011) time samples complete in 728.4966700077057!
# Running CPA for num_of_traces = 1140
# CPA attack for num_of_traces = 1140 and (490-1011) time samples complete in 740.0601489543915!
# Running CPA for num_of_traces = 1160
# CPA attack for num_of_traces = 1160 and (490-1011) time samples complete in 751.7973210811615!
# Running CPA for num_of_traces = 1180
# CPA attack for num_of_traces = 1180 and (490-1011) time samples complete in 763.3382210731506!
# Running CPA for num_of_traces = 1200
# CPA attack for num_of_traces = 1200 and (490-1011) time samples complete in 775.2102992534637!
# Running CPA for num_of_traces = 1220
# CPA attack for num_of_traces = 1220 and (490-1011) time samples complete in 786.9684410095215!
# Running CPA for num_of_traces = 1240
# CPA attack for num_of_traces = 1240 and (490-1011) time samples complete in 798.8010292053223!
# Running CPA for num_of_traces = 1260
# CPA attack for num_of_traces = 1260 and (490-1011) time samples complete in 810.8150899410248!
# Running CPA for num_of_traces = 1280
# CPA attack for num_of_traces = 1280 and (490-1011) time samples complete in 822.7102699279785!
# Running CPA for num_of_traces = 1300
# CPA attack for num_of_traces = 1300 and (490-1011) time samples complete in 834.8123619556427!
# Running CPA for num_of_traces = 1320
# CPA attack for num_of_traces = 1320 and (490-1011) time samples complete in 846.8000178337097!
# Running CPA for num_of_traces = 1340
# CPA attack for num_of_traces = 1340 and (490-1011) time samples complete in 859.0367591381073!
# Running CPA for num_of_traces = 1360
# CPA attack for num_of_traces = 1360 and (490-1011) time samples complete in 871.1632449626923!
# Running CPA for num_of_traces = 1380
# CPA attack for num_of_traces = 1380 and (490-1011) time samples complete in 883.6970858573914!
# Running CPA for num_of_traces = 1400
# CPA attack for num_of_traces = 1400 and (490-1011) time samples complete in 895.9963178634644!
# Running CPA for num_of_traces = 1420
# CPA attack for num_of_traces = 1420 and (490-1011) time samples complete in 908.6671659946442!
# Running CPA for num_of_traces = 1440
# CPA attack for num_of_traces = 1440 and (490-1011) time samples complete in 921.1056230068207!
# Running CPA for num_of_traces = 1460
# CPA attack for num_of_traces = 1460 and (490-1011) time samples complete in 933.7549629211426!
# Running CPA for num_of_traces = 1480
# CPA attack for num_of_traces = 1480 and (490-1011) time samples complete in 946.4357440471649!
# Running CPA for num_of_traces = 1500
# CPA attack for num_of_traces = 1500 and (490-1011) time samples complete in 959.1060240268707!
# Running CPA for num_of_traces = 1520
# CPA attack for num_of_traces = 1520 and (490-1011) time samples complete in 971.8153910636902!
# Running CPA for num_of_traces = 1540
# CPA attack for num_of_traces = 1540 and (490-1011) time samples complete in 984.6773340702057!
# Running CPA for num_of_traces = 1560
# CPA attack for num_of_traces = 1560 and (490-1011) time samples complete in 997.7392029762268!
# Running CPA for num_of_traces = 1580
# CPA attack for num_of_traces = 1580 and (490-1011) time samples complete in 1010.7571399211884!
# Running CPA for num_of_traces = 1600
# CPA attack for num_of_traces = 1600 and (490-1011) time samples complete in 1024.0073170661926!
# Running CPA for num_of_traces = 1620
# CPA attack for num_of_traces = 1620 and (490-1011) time samples complete in 1037.0995619297028!
# Running CPA for num_of_traces = 1640
# CPA attack for num_of_traces = 1640 and (490-1011) time samples complete in 1050.3641741275787!
# Running CPA for num_of_traces = 1660
# CPA attack for num_of_traces = 1660 and (490-1011) time samples complete in 1063.6195690631866!
# Running CPA for num_of_traces = 1680
# CPA attack for num_of_traces = 1680 and (490-1011) time samples complete in 1077.0249381065369!
# Running CPA for num_of_traces = 1700
# CPA attack for num_of_traces = 1700 and (490-1011) time samples complete in 1090.3461828231812!
# Running CPA for num_of_traces = 1720
# CPA attack for num_of_traces = 1720 and (490-1011) time samples complete in 1103.8425662517548!
# Running CPA for num_of_traces = 1740
# CPA attack for num_of_traces = 1740 and (490-1011) time samples complete in 1117.3455920219421!
# Running CPA for num_of_traces = 1760
# CPA attack for num_of_traces = 1760 and (490-1011) time samples complete in 1130.9103281497955!
# Running CPA for num_of_traces = 1780
# CPA attack for num_of_traces = 1780 and (490-1011) time samples complete in 1144.5955290794373!
# Running CPA for num_of_traces = 1800
# CPA attack for num_of_traces = 1800 and (490-1011) time samples complete in 1158.205039024353!
# Running CPA for num_of_traces = 1820
# CPA attack for num_of_traces = 1820 and (490-1011) time samples complete in 1171.9844238758087!
# Running CPA for num_of_traces = 1840
# CPA attack for num_of_traces = 1840 and (490-1011) time samples complete in 1185.7018740177155!
# Running CPA for num_of_traces = 1860
# CPA attack for num_of_traces = 1860 and (490-1011) time samples complete in 1199.7021729946136!
# Running CPA for num_of_traces = 1880
# CPA attack for num_of_traces = 1880 and (490-1011) time samples complete in 1213.6408491134644!
# Running CPA for num_of_traces = 1900
# CPA attack for num_of_traces = 1900 and (490-1011) time samples complete in 1227.5283651351929!
# Running CPA for num_of_traces = 1920
# CPA attack for num_of_traces = 1920 and (490-1011) time samples complete in 1241.480229139328!
# Running CPA for num_of_traces = 1940
# CPA attack for num_of_traces = 1940 and (490-1011) time samples complete in 1255.6772890090942!
# Running CPA for num_of_traces = 1960
# CPA attack for num_of_traces = 1960 and (490-1011) time samples complete in 1269.7307629585266!
# Running CPA for num_of_traces = 1980
# CPA attack for num_of_traces = 1980 and (490-1011) time samples complete in 1284.009702205658!
# Running CPA for num_of_traces = 2000
# CPA attack for num_of_traces = 2000 and (490-1011) time samples complete in 1298.3332860469818!
# Running CPA for num_of_traces = 2020
# CPA attack for num_of_traces = 2020 and (490-1011) time samples complete in 1312.458671092987!
# Running CPA for num_of_traces = 2040
# CPA attack for num_of_traces = 2040 and (490-1011) time samples complete in 1326.584860086441!
# Running CPA for num_of_traces = 2060
# CPA attack for num_of_traces = 2060 and (490-1011) time samples complete in 1340.8280172348022!
# Running CPA for num_of_traces = 2080
# CPA attack for num_of_traces = 2080 and (490-1011) time samples complete in 1355.2349030971527!
# Running CPA for num_of_traces = 2100
# CPA attack for num_of_traces = 2100 and (490-1011) time samples complete in 1369.8634040355682!
# Running CPA for num_of_traces = 2120
# CPA attack for num_of_traces = 2120 and (490-1011) time samples complete in 1385.1376280784607!
# Running CPA for num_of_traces = 2140
# CPA attack for num_of_traces = 2140 and (490-1011) time samples complete in 1399.8907420635223!
# Running CPA for num_of_traces = 2160
# CPA attack for num_of_traces = 2160 and (490-1011) time samples complete in 1414.6310851573944!
# Running CPA for num_of_traces = 2180
# CPA attack for num_of_traces = 2180 and (490-1011) time samples complete in 1429.4215250015259!
# Running CPA for num_of_traces = 2200
# CPA attack for num_of_traces = 2200 and (490-1011) time samples complete in 1444.0537259578705!
# Running CPA for num_of_traces = 2220
# CPA attack for num_of_traces = 2220 and (490-1011) time samples complete in 1458.8229591846466!
# Running CPA for num_of_traces = 2240
# CPA attack for num_of_traces = 2240 and (490-1011) time samples complete in 1473.6404531002045!
# Running CPA for num_of_traces = 2260
# CPA attack for num_of_traces = 2260 and (490-1011) time samples complete in 1488.4100069999695!
# Running CPA for num_of_traces = 2280
# CPA attack for num_of_traces = 2280 and (490-1011) time samples complete in 1503.27952003479!
# Running CPA for num_of_traces = 2300
# CPA attack for num_of_traces = 2300 and (490-1011) time samples complete in 1518.2700080871582!
# Running CPA for num_of_traces = 2320
# CPA attack for num_of_traces = 2320 and (490-1011) time samples complete in 1533.2645471096039!
# Running CPA for num_of_traces = 2340
# CPA attack for num_of_traces = 2340 and (490-1011) time samples complete in 1548.3781921863556!
# Running CPA for num_of_traces = 2360
# CPA attack for num_of_traces = 2360 and (490-1011) time samples complete in 1563.5144708156586!
# Running CPA for num_of_traces = 2380
# CPA attack for num_of_traces = 2380 and (490-1011) time samples complete in 1578.595027923584!
# Running CPA for num_of_traces = 2400
# CPA attack for num_of_traces = 2400 and (490-1011) time samples complete in 1593.7208099365234!
# Running CPA for num_of_traces = 2420
# CPA attack for num_of_traces = 2420 and (490-1011) time samples complete in 1609.0092511177063!
# Running CPA for num_of_traces = 2440
# CPA attack for num_of_traces = 2440 and (490-1011) time samples complete in 1624.258407831192!
# Running CPA for num_of_traces = 2460
# CPA attack for num_of_traces = 2460 and (490-1011) time samples complete in 1639.5049452781677!
# Running CPA for num_of_traces = 2480
# CPA attack for num_of_traces = 2480 and (490-1011) time samples complete in 1654.6987881660461!
# Running CPA for num_of_traces = 2500
# CPA attack for num_of_traces = 2500 and (490-1011) time samples complete in 1670.0613000392914!
# Running CPA for num_of_traces = 2520
# CPA attack for num_of_traces = 2520 and (490-1011) time samples complete in 1685.4932751655579!
# Running CPA for num_of_traces = 2540
# CPA attack for num_of_traces = 2540 and (490-1011) time samples complete in 1701.0144209861755!
# Running CPA for num_of_traces = 2560
# CPA attack for num_of_traces = 2560 and (490-1011) time samples complete in 1716.4943780899048!
# Running CPA for num_of_traces = 2580
# CPA attack for num_of_traces = 2580 and (490-1011) time samples complete in 1731.877818107605!
# Running CPA for num_of_traces = 2600
# CPA attack for num_of_traces = 2600 and (490-1011) time samples complete in 1747.4100379943848!
# Running CPA for num_of_traces = 2620
# CPA attack for num_of_traces = 2620 and (490-1011) time samples complete in 1763.1164650917053!
# Running CPA for num_of_traces = 2640
# CPA attack for num_of_traces = 2640 and (490-1011) time samples complete in 1778.8101391792297!
# Running CPA for num_of_traces = 2660
# CPA attack for num_of_traces = 2660 and (490-1011) time samples complete in 1794.597239971161!
# Running CPA for num_of_traces = 2680
# CPA attack for num_of_traces = 2680 and (490-1011) time samples complete in 1810.3389921188354!
# Running CPA for num_of_traces = 2700
# CPA attack for num_of_traces = 2700 and (490-1011) time samples complete in 1826.15918302536!
# Running CPA for num_of_traces = 2720
# CPA attack for num_of_traces = 2720 and (490-1011) time samples complete in 1841.912682056427!
# Running CPA for num_of_traces = 2740
# CPA attack for num_of_traces = 2740 and (490-1011) time samples complete in 1857.7850930690765!
# Running CPA for num_of_traces = 2760
# CPA attack for num_of_traces = 2760 and (490-1011) time samples complete in 1873.7513139247894!
# Running CPA for num_of_traces = 2780
# CPA attack for num_of_traces = 2780 and (490-1011) time samples complete in 1889.6915321350098!
# Running CPA for num_of_traces = 2800
# CPA attack for num_of_traces = 2800 and (490-1011) time samples complete in 1905.692039012909!
# Running CPA for num_of_traces = 2820
# CPA attack for num_of_traces = 2820 and (490-1011) time samples complete in 1921.7542440891266!
# Running CPA for num_of_traces = 2840
# CPA attack for num_of_traces = 2840 and (490-1011) time samples complete in 1937.8670670986176!
# Running CPA for num_of_traces = 2860
# CPA attack for num_of_traces = 2860 and (490-1011) time samples complete in 1954.0057258605957!
# Running CPA for num_of_traces = 2880
# CPA attack for num_of_traces = 2880 and (490-1011) time samples complete in 1970.181764125824!
# Running CPA for num_of_traces = 2900
# CPA attack for num_of_traces = 2900 and (490-1011) time samples complete in 1986.3862268924713!
# Running CPA for num_of_traces = 2920
# CPA attack for num_of_traces = 2920 and (490-1011) time samples complete in 2002.571801185608!
# Running CPA for num_of_traces = 2940
# CPA attack for num_of_traces = 2940 and (490-1011) time samples complete in 2018.6446928977966!
# Running CPA for num_of_traces = 2960
# CPA attack for num_of_traces = 2960 and (490-1011) time samples complete in 2034.895457983017!
# Running CPA for num_of_traces = 2980
# CPA attack for num_of_traces = 2980 and (490-1011) time samples complete in 2051.348765850067!
# Running CPA for num_of_traces = 3000
# CPA attack for num_of_traces = 3000 and (490-1011) time samples complete in 2067.900805234909!
# Running CPA for num_of_traces = 3020
# CPA attack for num_of_traces = 3020 and (490-1011) time samples complete in 2084.6248140335083!
# Running CPA for num_of_traces = 3040
# CPA attack for num_of_traces = 3040 and (490-1011) time samples complete in 2100.9598441123962!
# Running CPA for num_of_traces = 3060
# CPA attack for num_of_traces = 3060 and (490-1011) time samples complete in 2117.299772977829!
# Running CPA for num_of_traces = 3080
# CPA attack for num_of_traces = 3080 and (490-1011) time samples complete in 2133.6209568977356!
# Running CPA for num_of_traces = 3100
# CPA attack for num_of_traces = 3100 and (490-1011) time samples complete in 2149.9954328536987!
# Running CPA for num_of_traces = 3120
# CPA attack for num_of_traces = 3120 and (490-1011) time samples complete in 2166.3869519233704!
# Running CPA for num_of_traces = 3140
# CPA attack for num_of_traces = 3140 and (490-1011) time samples complete in 2182.9545159339905!
# Running CPA for num_of_traces = 3160
# CPA attack for num_of_traces = 3160 and (490-1011) time samples complete in 2199.4503560066223!
# Running CPA for num_of_traces = 3180
# CPA attack for num_of_traces = 3180 and (490-1011) time samples complete in 2216.0013089179993!
# Running CPA for num_of_traces = 3200
# CPA attack for num_of_traces = 3200 and (490-1011) time samples complete in 2232.5216150283813!
# Running CPA for num_of_traces = 3220
# CPA attack for num_of_traces = 3220 and (490-1011) time samples complete in 2249.1046760082245!
# Running CPA for num_of_traces = 3240
# CPA attack for num_of_traces = 3240 and (490-1011) time samples complete in 2265.68935918808!
# Running CPA for num_of_traces = 3260
# CPA attack for num_of_traces = 3260 and (490-1011) time samples complete in 2282.3359060287476!
# Running CPA for num_of_traces = 3280
# CPA attack for num_of_traces = 3280 and (490-1011) time samples complete in 2298.992630004883!
# Running CPA for num_of_traces = 3300
# CPA attack for num_of_traces = 3300 and (490-1011) time samples complete in 2315.6989612579346!
# Running CPA for num_of_traces = 3320
# CPA attack for num_of_traces = 3320 and (490-1011) time samples complete in 2332.469190120697!
# Running CPA for num_of_traces = 3340
# CPA attack for num_of_traces = 3340 and (490-1011) time samples complete in 2349.3157670497894!
# Running CPA for num_of_traces = 3360
# CPA attack for num_of_traces = 3360 and (490-1011) time samples complete in 2366.056340932846!
# Running CPA for num_of_traces = 3380
# CPA attack for num_of_traces = 3380 and (490-1011) time samples complete in 2382.929036140442!
# Running CPA for num_of_traces = 3400
# CPA attack for num_of_traces = 3400 and (490-1011) time samples complete in 2399.8704199790955!
# Running CPA for num_of_traces = 3420
# CPA attack for num_of_traces = 3420 and (490-1011) time samples complete in 2417.2298748493195!
# Running CPA for num_of_traces = 3440
# CPA attack for num_of_traces = 3440 and (490-1011) time samples complete in 2434.1584498882294!
# Running CPA for num_of_traces = 3460
# CPA attack for num_of_traces = 3460 and (490-1011) time samples complete in 2451.2839410305023!
# Running CPA for num_of_traces = 3480
# CPA attack for num_of_traces = 3480 and (490-1011) time samples complete in 2468.3247039318085!
# Running CPA for num_of_traces = 3500
# CPA attack for num_of_traces = 3500 and (490-1011) time samples complete in 2485.4634160995483!
# Running CPA for num_of_traces = 3520
# CPA attack for num_of_traces = 3520 and (490-1011) time samples complete in 2502.675749063492!
# Running CPA for num_of_traces = 3540
# CPA attack for num_of_traces = 3540 and (490-1011) time samples complete in 2519.910140991211!
# Running CPA for num_of_traces = 3560
# CPA attack for num_of_traces = 3560 and (490-1011) time samples complete in 2537.1660339832306!
# Running CPA for num_of_traces = 3580
# CPA attack for num_of_traces = 3580 and (490-1011) time samples complete in 2554.4705259799957!
# Running CPA for num_of_traces = 3600
# CPA attack for num_of_traces = 3600 and (490-1011) time samples complete in 2571.7934350967407!
# Running CPA for num_of_traces = 3620
# CPA attack for num_of_traces = 3620 and (490-1011) time samples complete in 2589.1967470645905!
# Running CPA for num_of_traces = 3640
# CPA attack for num_of_traces = 3640 and (490-1011) time samples complete in 2606.6233689785004!
# Running CPA for num_of_traces = 3660
# CPA attack for num_of_traces = 3660 and (490-1011) time samples complete in 2624.104737997055!
# Running CPA for num_of_traces = 3680
# CPA attack for num_of_traces = 3680 and (490-1011) time samples complete in 2641.5915110111237!
# Running CPA for num_of_traces = 3700
# CPA attack for num_of_traces = 3700 and (490-1011) time samples complete in 2659.364192008972!
# Running CPA for num_of_traces = 3720
# CPA attack for num_of_traces = 3720 and (490-1011) time samples complete in 2676.9272491931915!
# Running CPA for num_of_traces = 3740
# CPA attack for num_of_traces = 3740 and (490-1011) time samples complete in 2694.558684825897!
# Running CPA for num_of_traces = 3760
# CPA attack for num_of_traces = 3760 and (490-1011) time samples complete in 2712.263988018036!
# Running CPA for num_of_traces = 3780
# CPA attack for num_of_traces = 3780 and (490-1011) time samples complete in 2729.977100133896!
# Running CPA for num_of_traces = 3800
# CPA attack for num_of_traces = 3800 and (490-1011) time samples complete in 2747.7210760116577!
# Running CPA for num_of_traces = 3820
# CPA attack for num_of_traces = 3820 and (490-1011) time samples complete in 2765.469600915909!
# Running CPA for num_of_traces = 3840
# CPA attack for num_of_traces = 3840 and (490-1011) time samples complete in 2783.305634021759!
# Running CPA for num_of_traces = 3860
# CPA attack for num_of_traces = 3860 and (490-1011) time samples complete in 2801.2043561935425!
# Running CPA for num_of_traces = 3880
# CPA attack for num_of_traces = 3880 and (490-1011) time samples complete in 2819.1188769340515!
# Running CPA for num_of_traces = 3900
# CPA attack for num_of_traces = 3900 and (490-1011) time samples complete in 2837.0393710136414!
# Running CPA for num_of_traces = 3920
# CPA attack for num_of_traces = 3920 and (490-1011) time samples complete in 2854.9622399806976!
# Running CPA for num_of_traces = 3940
# CPA attack for num_of_traces = 3940 and (490-1011) time samples complete in 2872.9950652122498!
# Running CPA for num_of_traces = 3960
# CPA attack for num_of_traces = 3960 and (490-1011) time samples complete in 2891.0396690368652!
# Running CPA for num_of_traces = 3980
# CPA attack for num_of_traces = 3980 and (490-1011) time samples complete in 2909.193689107895!
# Running CPA for num_of_traces = 4000
# CPA attack for num_of_traces = 4000 and (490-1011) time samples complete in 2927.348440170288!
# Running CPA for num_of_traces = 4020
# CPA attack for num_of_traces = 4020 and (490-1011) time samples complete in 2945.55517411232!
# Running CPA for num_of_traces = 4040
# CPA attack for num_of_traces = 4040 and (490-1011) time samples complete in 2964.0053629875183!
# Running CPA for num_of_traces = 4060
# CPA attack for num_of_traces = 4060 and (490-1011) time samples complete in 2982.8249230384827!
# Running CPA for num_of_traces = 4080
# CPA attack for num_of_traces = 4080 and (490-1011) time samples complete in 3001.0667510032654!
# Running CPA for num_of_traces = 4100
# CPA attack for num_of_traces = 4100 and (490-1011) time samples complete in 3019.3666219711304!
# Running CPA for num_of_traces = 4120
# CPA attack for num_of_traces = 4120 and (490-1011) time samples complete in 3037.718080997467!
# Running CPA for num_of_traces = 4140
# CPA attack for num_of_traces = 4140 and (490-1011) time samples complete in 3056.17219209671!
# Running CPA for num_of_traces = 4160
# CPA attack for num_of_traces = 4160 and (490-1011) time samples complete in 3074.6057929992676!
# Running CPA for num_of_traces = 4180
# CPA attack for num_of_traces = 4180 and (490-1011) time samples complete in 3093.0672550201416!
# Running CPA for num_of_traces = 4200
# CPA attack for num_of_traces = 4200 and (490-1011) time samples complete in 3111.6643810272217!
# Running CPA for num_of_traces = 4220
# CPA attack for num_of_traces = 4220 and (490-1011) time samples complete in 3130.308130979538!
# Running CPA for num_of_traces = 4240
# CPA attack for num_of_traces = 4240 and (490-1011) time samples complete in 3149.1409950256348!
# Running CPA for num_of_traces = 4260
# CPA attack for num_of_traces = 4260 and (490-1011) time samples complete in 3167.8668401241302!
# Running CPA for num_of_traces = 4280
# CPA attack for num_of_traces = 4280 and (490-1011) time samples complete in 3186.8424780368805!
# Running CPA for num_of_traces = 4300
# CPA attack for num_of_traces = 4300 and (490-1011) time samples complete in 3205.8677361011505!
# Running CPA for num_of_traces = 4320
# CPA attack for num_of_traces = 4320 and (490-1011) time samples complete in 3224.9567799568176!
# Running CPA for num_of_traces = 4340
# CPA attack for num_of_traces = 4340 and (490-1011) time samples complete in 3243.8418650627136!
# Running CPA for num_of_traces = 4360
# CPA attack for num_of_traces = 4360 and (490-1011) time samples complete in 3262.7107269763947!
# Running CPA for num_of_traces = 4380
# CPA attack for num_of_traces = 4380 and (490-1011) time samples complete in 3281.620803117752!
# Running CPA for num_of_traces = 4400
# CPA attack for num_of_traces = 4400 and (490-1011) time samples complete in 3300.462703227997!
# Running CPA for num_of_traces = 4420
# CPA attack for num_of_traces = 4420 and (490-1011) time samples complete in 3319.8618109226227!
# Running CPA for num_of_traces = 4440
# CPA attack for num_of_traces = 4440 and (490-1011) time samples complete in 3338.9177861213684!
# Running CPA for num_of_traces = 4460
# CPA attack for num_of_traces = 4460 and (490-1011) time samples complete in 3357.9530968666077!
# Running CPA for num_of_traces = 4480
# CPA attack for num_of_traces = 4480 and (490-1011) time samples complete in 3377.023318052292!
# Running CPA for num_of_traces = 4500
# CPA attack for num_of_traces = 4500 and (490-1011) time samples complete in 3396.0775649547577!
# Running CPA for num_of_traces = 4520
# CPA attack for num_of_traces = 4520 and (490-1011) time samples complete in 3415.3289341926575!
# Running CPA for num_of_traces = 4540
# CPA attack for num_of_traces = 4540 and (490-1011) time samples complete in 3434.518429994583!
# Running CPA for num_of_traces = 4560
# CPA attack for num_of_traces = 4560 and (490-1011) time samples complete in 3453.7855191230774!
# Running CPA for num_of_traces = 4580
# CPA attack for num_of_traces = 4580 and (490-1011) time samples complete in 3473.0454530715942!
# Running CPA for num_of_traces = 4600
# CPA attack for num_of_traces = 4600 and (490-1011) time samples complete in 3492.3500640392303!
# Running CPA for num_of_traces = 4620
# CPA attack for num_of_traces = 4620 and (490-1011) time samples complete in 3511.743978023529!
# Running CPA for num_of_traces = 4640
# CPA attack for num_of_traces = 4640 and (490-1011) time samples complete in 3531.1113131046295!
# Running CPA for num_of_traces = 4660
# CPA attack for num_of_traces = 4660 and (490-1011) time samples complete in 3550.4924790859222!
# Running CPA for num_of_traces = 4680
# CPA attack for num_of_traces = 4680 and (490-1011) time samples complete in 3569.9170200824738!
# Running CPA for num_of_traces = 4700
# CPA attack for num_of_traces = 4700 and (490-1011) time samples complete in 3589.5227179527283!
# Running CPA for num_of_traces = 4720
# CPA attack for num_of_traces = 4720 and (490-1011) time samples complete in 3609.0158059597015!
# Running CPA for num_of_traces = 4740
# CPA attack for num_of_traces = 4740 and (490-1011) time samples complete in 3628.718039035797!
# Running CPA for num_of_traces = 4760
# CPA attack for num_of_traces = 4760 and (490-1011) time samples complete in 3648.330549955368!
# Running CPA for num_of_traces = 4780
# CPA attack for num_of_traces = 4780 and (490-1011) time samples complete in 3668.163087129593!
# Running CPA for num_of_traces = 4800
# CPA attack for num_of_traces = 4800 and (490-1011) time samples complete in 3687.9247620105743!
# Running CPA for num_of_traces = 4820
# CPA attack for num_of_traces = 4820 and (490-1011) time samples complete in 3707.6053380966187!
# Running CPA for num_of_traces = 4840
# CPA attack for num_of_traces = 4840 and (490-1011) time samples complete in 3727.322551012039!
# Running CPA for num_of_traces = 4860
# CPA attack for num_of_traces = 4860 and (490-1011) time samples complete in 3747.1008372306824!
# Running CPA for num_of_traces = 4880
# CPA attack for num_of_traces = 4880 and (490-1011) time samples complete in 3767.0115818977356!
# Running CPA for num_of_traces = 4900
# CPA attack for num_of_traces = 4900 and (490-1011) time samples complete in 3787.1425132751465!
# Running CPA for num_of_traces = 4920
# CPA attack for num_of_traces = 4920 and (490-1011) time samples complete in 3807.5712599754333!
# Running CPA for num_of_traces = 4940
# CPA attack for num_of_traces = 4940 and (490-1011) time samples complete in 3827.8366100788116!
# Running CPA for num_of_traces = 4960
# CPA attack for num_of_traces = 4960 and (490-1011) time samples complete in 3848.068529844284!
# Running CPA for num_of_traces = 4980
# CPA attack for num_of_traces = 4980 and (490-1011) time samples complete in 3868.0801360607147!
# Running CPA for num_of_traces = 5000
# CPA attack for num_of_traces = 5000 and (490-1011) time samples complete in 3888.236836194992!

# %% [markdown]
# # Attack on protected traces

# %%
folder_name="protected"

# %%
def get_inputs(folder_name):
    with open(folder_name + '/inputs.txt') as f:
        inputs_arr = f.read().splitlines()
    f.close()
    inputs_arr = np.array(inputs_arr)
    inputs_arr = inputs_arr.astype(float)
    return inputs_arr

# %%
inputs_pro = get_inputs(folder_name)

# %%
hypothetical_leakages = get_hypothetical_leakages(num_of_traces=1000000, inputs_arr=inputs_pro)

# %%
#protected case
num_trace = []
for n in range(3,99,3):
    num_trace.append(n)

for n in range(100, 1000000, 10000):
    num_trace.append(n)
num_trace.append(999999)
len(num_trace)

# %%
def compute_correlation(time_sample, num_trace, hypothetical_leakages):
    #get all data for the time_sample
    trace = []
    #total number of experiments to run
    number_of_experiments = len(num_trace)
    #all correlations, for each number of traces and for each weight value
    r_abs = [[] for i in range(total_num_of_weight)]

    for i in range(num_of_traces):
        with open(folder_name + '/trace_'+str(i)+'.txt') as f:
            lines = f.read().splitlines()
            trace.append(lines[time_sample])
            f.close()
    
    trace = np.array(trace)
    trace = trace.astype(float)
    
    print("got traces")
    for trace_no in num_trace:
        
        ind = [j for j in range(trace_no)]
        
        trace_subset = trace[ind]
        hypoleak_subset = hypothetical_leakages[:,ind]#extract the corresponding hypothetical leakages
        
        for weight_index in range(total_num_of_weight):
            corr_coef = np.corrcoef(hypoleak_subset[weight_index],trace_subset)[0][1]
            r_abs[weight_index].append(abs(corr_coef))
    
    return r_abs

# %%
start = 490
end_pro = 4301
total_pro = end_pro - start

# %%
def CPA_protected(hypothetical_leakages, num_trace):
    total_experiment = len(num_trace)
    r_all = [[[0 for k in range(total_pro)] for i in range(total_num_of_weight)]for j in range(total_experiment)]
    for i in range(total_pro):
        time_sample = i + start
        print("computing for time sample " + str(time_sample))
        r_t = compute_correlation(time_sample, num_trace, hypothetical_leakages)
        for j in range(total_experiment):
            for weight_index in range(total_num_of_weight):
                r_all[j][weight_index][i] = r_t[weight_index][j]
    return r_all
# Out:
# 133

# %%
def run_CPA_n_traces(total_ts, start_ts, trace_arr, save_folder, filename, arr_num_traces, hypothetical_leakages):
    # initialize np arrays for highest correlation results
    arr_max_sign_bit = np.array([])
    arr_max_true_sign_bit = np.array([])
    arr_max_exponent_bits = np.array([])
    arr_max_true_exponent_bits = np.array([])
    arr_max_byte_two = np.array([])
    arr_max_true_byte_two = np.array([])
    arr_max_byte_three = np.array([])
    arr_max_true_byte_three = np.array([])
    arr_max_byte_four = np.array([])
    arr_max_true_byte_four = np.array([])

    total_experiment = len(arr_num_traces)
    r_all = CPA_protected(hypothetical_leakages=hypothetical_leakages, num_trace=arr_num_traces)

    for i in range(total_experiment):        
        

        r = r_all[i]

        correlations_sign_bit = recover_byte(r, 0, total_ts)
        correlations_exponent_bits = recover_byte(r,1, total_ts)
        correlations_byte_two = recover_byte(r, 2, total_ts)
        correlations_byte_three = recover_byte(r, 3, total_ts)
        correlations_byte_four = recover_byte(r, 4, total_ts)

        max_sign_bit, max_true_sign_bit = find_max_and_max_true(correlations_sign_bit, true_sign_bit)
        max_exponent_bits, max_true_exponent_bits = find_max_and_max_true(correlations_exponent_bits, true_exponent_bits)
        max_byte_two, max_true_byte_two = find_max_and_max_true(correlations_byte_two, true_byte_two)
        max_byte_three, max_true_byte_three = find_max_and_max_true(correlations_byte_three, true_byte_three)
        max_byte_four, max_true_byte_four = find_max_and_max_true(correlations_byte_four, true_byte_four)

        arr_max_sign_bit = np.append(arr_max_sign_bit, max_sign_bit)
        arr_max_true_sign_bit = np.append(arr_max_true_sign_bit, max_true_sign_bit)
        arr_max_exponent_bits = np.append(arr_max_exponent_bits, max_exponent_bits)
        arr_max_true_exponent_bits = np.append(arr_max_true_exponent_bits, max_true_exponent_bits)
        arr_max_byte_two = np.append(arr_max_byte_two, max_byte_two)
        arr_max_true_byte_two = np.append(arr_max_true_byte_two, max_true_byte_two)
        arr_max_byte_three = np.append(arr_max_byte_three, max_byte_three)
        arr_max_true_byte_three = np.append(arr_max_true_byte_three, max_true_byte_three)
        arr_max_byte_four = np.append(arr_max_byte_four, max_byte_four)
        arr_max_true_byte_four = np.append(arr_max_true_byte_four, max_true_byte_four)

        if i%100000 == 0:
            saveplot(save_folder, filename + "sign_bit", arr_max_sign_bit, arr_num_traces)
            saveplot(save_folder, filename + "true_sign_bit", arr_max_true_sign_bit, arr_num_traces)
            saveplot(save_folder, filename + "exponent_bits", arr_max_exponent_bits, arr_num_traces)
            saveplot(save_folder, filename + "true_exponent_bits", arr_max_true_exponent_bits, arr_num_traces)
            saveplot(save_folder, filename + "first_byte", arr_max_byte_two, arr_num_traces)
            saveplot(save_folder, filename + "true_first_byte", arr_max_true_byte_two, arr_num_traces)
            saveplot(save_folder, filename + "second_byte", arr_max_byte_three, arr_num_traces)
            saveplot(save_folder, filename + "true_second_byte", arr_max_true_byte_three, arr_num_traces)
            saveplot(save_folder, filename + "last_bits", arr_max_byte_four, arr_num_traces)
            saveplot(save_folder, filename + "true_last_bits", arr_max_true_byte_four, arr_num_traces)
            
    saveplot(save_folder, filename + "sign_bit", arr_max_sign_bit, arr_num_traces)
    saveplot(save_folder, filename + "true_sign_bit", arr_max_true_sign_bit, arr_num_traces)
    saveplot(save_folder, filename + "exponent_bits", arr_max_exponent_bits, arr_num_traces)
    saveplot(save_folder, filename + "true_exponent_bits", arr_max_true_exponent_bits, arr_num_traces)
    saveplot(save_folder, filename + "first_byte", arr_max_byte_two, arr_num_traces)
    saveplot(save_folder, filename + "true_first_byte", arr_max_true_byte_two, arr_num_traces)
    saveplot(save_folder, filename + "second_byte", arr_max_byte_three, arr_num_traces)
    saveplot(save_folder, filename + "true_second_byte", arr_max_true_byte_three, arr_num_traces)
    saveplot(save_folder, filename + "last_bits", arr_max_byte_four, arr_num_traces)
    saveplot(save_folder, filename + "true_last_bits", arr_max_true_byte_four, arr_num_traces)
    
    return

# %%
def compute_correlation(time_sample, num_trace, hypothetical_leakages):

    number_of_experiments = len(num_trace)
    #all correlations, for each number of traces and for each weight value
    r_abs = np.zeros((number_of_experiments, total_num_of_weight))


    # Efficiently read only the required line from each trace file
    def read_time_sample(i):
        with open(f"{folder_name}/trace_{i}.txt") as f:
            for _ in range(time_sample):  # Skip lines up to time_sample
                next(f)
            return float(f.readline().strip())  # Read the required line

    # Read all traces efficiently
    traces = np.fromiter((read_time_sample(i) for i in range(num_of_traces)), dtype=np.float64)

    
    for index in range(number_of_experiments):
        trace_no = num_trace[index]
        
        trace_subset = traces[:trace_no]  # Select the first 'trace_no' traces
        hypoleak_subset = hypothetical_leakages[:, :trace_no]  # Select corresponding hypothetical leakages
        
        # Compute correlation efficiently using vectorized NumPy operations
        mean_trace = np.mean(trace_subset)
        mean_hypo = np.mean(hypoleak_subset, axis=1)

        num = np.sum((hypoleak_subset - mean_hypo[:, None]) * (trace_subset - mean_trace), axis=1)
        den = np.sqrt(np.sum((hypoleak_subset - mean_hypo[:, None])**2, axis=1) * np.sum((trace_subset - mean_trace)**2))

        r_abs[index, :] = np.abs(num / den)  # Compute absolute correlation


            
    return r_abs


def CPA_protected(hypothetical_leakages, num_trace):
    total_experiment = len(num_trace)
    
    # Initialize r_all as a NumPy array instead of a nested list
    r_all = np.zeros((total_experiment, total_num_of_weight, total_pro))
    
    for i in range(total_pro):
        time_sample = i + start
        if i%100 == 0:
            print(f"computing for time sample {time_sample}")
        
        # Compute correlation
        r_t = compute_correlation(time_sample, num_trace, hypothetical_leakages)  # Assuming r_t has shape (total_experiment, total_num_of_weight)
        
        # Use NumPy slicing instead of nested loops
        r_all[:, :, i] = r_t  # Assign entire 2D slice in one step

    return r_all

# %%
def CPA_protected(num_trace, hypothetical_leakages):
    total_experiment = len(num_trace)

    # Initialize r_all using NumPy
    r_all = np.zeros((total_experiment, total_num_of_weight, total_pro))
    
    # Function to read a specific line from trace files efficiently
    def read_time_sample(i, time_sample):
        with open(f"{folder_name}/trace_{i}.txt") as f:
            for _ in range(time_sample):  # Skip lines up to time_sample
                next(f)
            return float(f.readline().strip())  # Read the required line    

    for i in range(total_pro):
        time_sample = i + start
        if i % 100 == 0:
            print(f"Computing for time sample {time_sample}")

        # Read only necessary time samples from traces
        traces = np.fromiter((read_time_sample(i, time_sample) for i in range(max(num_trace))), dtype=np.float64)

        # Compute correlation for each experiment
        for index, trace_no in enumerate(num_trace):
            trace_subset = traces[:trace_no]  # Select relevant traces
            hypoleak_subset = hypothetical_leakages[:, :trace_no]  # Select corresponding hypothetical leakages

            # Compute correlation efficiently
            mean_trace = np.mean(trace_subset)
            mean_hypo = np.mean(hypoleak_subset, axis=1)

            num = np.sum((hypoleak_subset - mean_hypo[:, None]) * (trace_subset - mean_trace), axis=1)
            den = np.sqrt(np.sum((hypoleak_subset - mean_hypo[:, None])**2, axis=1) * np.sum((trace_subset - mean_trace)**2))

            r_all[index, :, i] = np.abs(num / den)  # Store absolute correlation

    return r_all

# %%
def CPA_protected(num_trace, hypothetical_leakages):
    total_experiment = len(num_trace)

    # Initialize r_all using NumPy
    r_all = np.zeros((total_experiment, total_num_of_weight, total_pro))

    # Function to read a specific line from trace files efficiently
    def read_time_sample(i, time_sample):
        with open(f"{folder_name}/trace_{i}.txt") as f:
            for _ in range(time_sample):  # Skip lines up to time_sample
                next(f)
            return float(f.readline().strip())  # Read the required line    

    # Precompute statistics for hypothetical leakages
    precomputed_means = []
    precomputed_variances = []
    
    for index, trace_no in enumerate(num_trace):
        hypoleak_subset = hypothetical_leakages[:, :trace_no]  # Select corresponding hypothetical leakages

        mean_hypo = np.mean(hypoleak_subset, axis=1)  # Compute mean once
        var_hypo = np.sum((hypoleak_subset - mean_hypo[:, None])**2, axis=1)  # Compute variance sum once

        precomputed_means.append(mean_hypo)
        precomputed_variances.append(var_hypo)

    # Convert to NumPy arrays for faster indexing
    precomputed_means = np.array(precomputed_means)
    precomputed_variances = np.array(precomputed_variances)

    for i in range(total_pro):
        time_sample = i + start
        if i % 100 == 0:
            print(f"Computing for time sample {time_sample}")

        # Read only necessary time samples from traces
        traces = np.fromiter((read_time_sample(i, time_sample) for i in range(max(num_trace))), dtype=np.float64)

        for index, trace_no in enumerate(num_trace):
            trace_subset = traces[:trace_no]  # Select relevant traces
            
            mean_trace = np.mean(trace_subset)
            trace_dev = trace_subset - mean_trace
            var_trace = np.sum(trace_dev**2)

            num = np.sum((hypothetical_leakages[:, :trace_no] - precomputed_means[index][:, None]) * trace_dev, axis=1)
            den = np.sqrt(precomputed_variances[index] * var_trace)

            r_all[index, :, i] = np.abs(num / den)  # Store absolute correlation

    return r_all
